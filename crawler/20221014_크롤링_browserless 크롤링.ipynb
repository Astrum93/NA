# %% [markdown]
# # requests
#
# requests는 브라우저 없이 파이썬에서 다이렉트로 서버에 http 요청을 넣습니다.
#
# 요청을 받은 페이지는 해당 페이지의 소스코드를 파이썬 내부로 전송해줍니다.
#
# 단, 버튼 클릭이나 광고 닫기 등의 작업은 애초에 브라우저가 없기때문에 불가능하고
#
# 오로지 특정 주소로 접속했을때 최초에 전송되는 페이지 코드만 가져올 수 있습니다.
#
# 대신 물리 브라우저를 직접 켜지 않고, 명목상으로 요청만 하기 때문에
#
# 속도나 리소스면에서는 훨씬 우월합니다.

# %% [markdown]
# - 1. 내가 브자우저로 특정 서버 주소를 쳐서 접속시도를 합니다.
# - 2. 서버에 내가 접속한다는 요청이 들어갑니다.
# - 3. 서버가 요청에 응답 하면서 response 데이터를 함께 전송합니다.
# - 4. 브라우저가 받은 데이터를 해석해서 내 PC에 반영합니다.
#
#      ▶웹 사이트 접속이었으면 소스코드를 받아와서
#        사람이 볼 수 있도록 자동으로 그려줍니다.( 랜더링 해줍니다.)
#
#      ▶게임이면 해당 명령어가 들어가서 게임 상황에 반영됩니다.

# %%
# requests, beautifulsoup, time 임포트
import requests
from bs4 import BeautifulSoup
import time

# %%
# 특정 주소에 대한 요청은 requests.get("주소") 로 합니다.
# 요청에 대한 서버의 응답 (response)는 req 변수에 저장했습니다.
req = requests.get("https://www.naver.com")

# %%
# http 소스코드 읽어오기 (selenium 의 .text와 문법은 같으나 기능이 다름에 주의)
# req.text를 이용하면 셀레니움의 driver.page_source와 동일한 코드를 받아옵니다.
req.text
source = req.text

# %%
# http 헤더 가져오기
# 요청에 따른 상세 정보를 보여줍니다. 지금은 이런게 있다는것만 체크해주세요.
req.headers
# Out:
# {'Server': 'NWS', 'Date': 'Fri, 14 Oct 2022 01:43:28 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'PM_CK_loc=eeb1b259a03c465783af0c5c528ee7b7f75400c8075582247a7d434d73103936; Expires=Sat, 15 Oct 2022 01:43:28 GMT; Path=/; HttpOnly', 'Cache-Control': 'no-cache, no-store, must-revalidate', 'Pragma': 'no-cache', 'P3P': 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"', 'X-Frame-Options': 'DENY', 'X-XSS-Protection': '1; mode=block', 'Content-Encoding': 'gzip', 'Strict-Transport-Security': 'max-age=63072000; includeSubdomains', 'Referrer-Policy': 'unsafe-url'}

# %%
# http 상태코드 가져오기
# 200은 정상접속을 나타낸다.

req.status_code
# Out:
# 200

# %% [markdown]
# #### 그림으로 배우는 HTTP & Network basic 책
# #### 성공과 실패를 결정하는 1%의 네트워크 원리 책
# #### HTTP 완벽 가이드

# %% [markdown]
# # 알라딘 베스트셀러 7페이지
#
# 1. requests를 이용해서 해 주세요.
# 2. beautifulsoup 구간부터는 selenium을 활용한 크롤링과 차이가 없습니다.

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import time

# %%
# 요정할 페이지 입력
req = requests.get("https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=0&page=7&cnt=1000&SortOrder=1")

# %%
# reponse 받은 소스를 변수에 저장
source = req.text

# %%
# 파싱
parsed_source = BeautifulSoup(source, "html.parser")
# 책에 대한 정보 가져오기
div_books_list= parsed_source.find_all("div", class_="ss_book_box")

# 
for books in div_books_list:
    li_books_list = books.find_all("li")
    
    if(li_books_list[1].text[0] == '['):
        print(li_books_list[1].text)
        print(li_books_list[2].text)
        print(li_books_list[3].text)
    else:
        print(li_books_list[0].text)
        print(li_books_list[1].text)
        print(li_books_list[2].text)
print("------------------------------------------------------")
# Out:
# [국내도서] 세상 쉬운 영문법
# 윤여홍 (지은이) | 시간과공간사 | 2022년 10월
# 19,800원 → 17,820원 (10%할인),  마일리지 990원 (5% 적립)
# [국내도서] 어떻게 말해줘야 할까 (60만 부 기념 한정판 리커버)
# 오은영 (지은이), 차상미 (그림) | 김영사 | 2022년 7월
# 17,500원 → 15,750원 (10%할인),  마일리지 870원 (5% 적립)
# [국내도서] 브라질에 비가 내리면 스타벅스 주식을 사라
# 피터 나바로 (지은이), 이창식 (옮긴이), 윤지호 (감수) | 에프엔미디어 | 2022년 4월
# 18,000원 → 16,200원 (10%할인),  마일리지 900원 (5% 적립)
# [국내도서] 재수사 2
# 장강명 (지은이) | 은행나무 | 2022년 8월
# 16,000원 → 14,400원 (10%할인),  마일리지 800원 (5% 적립)
# [국내도서] 뇌, 욕망의 비밀을 풀다
# 한스-게오르크 호이젤 (지은이), 강영옥, 김신종, 한윤진 (옮긴이) | 비즈니스북스 | 2019년 10월
# 18,000원 → 16,200원 (10%할인),  마일리지 900원 (5% 적립)
# [국내도서] 임신 출산 육아 대백과 (2022~2023년 개정판)
# 삼성출판사 편집부 (엮은이) | 삼성출판사 | 2022년 7월
# 19,500원 → 17,550원 (10%할인),  마일리지 970원 (5% 적립)
# [국내도서] 부동산 경매로 1년 만에 꼬마빌딩주 되다
# 김상준 (지은이) | 매일경제신문사 | 2022년 9월
# 18,000원 → 16,200원 (10%할인),  마일리지 900원 (5% 적립)
# [국내도서] 사로잡는 얼굴들
# 이사 레슈코 (지은이), 김민주 (옮긴이) | 가망서사 | 2022년 9월
# 28,000원 → 25,200원 (10%할인),  마일리지 1,400원 (5% 적립)
# [국내도서] 부부 이상, 연인 미만. 1~2 합본판
# 카나마루 유키 (지은이), 송재희 (옮긴이) | 디앤씨미디어(주)(D&C미디어) | 2022년 10월
# 12,000원 → 10,800원 (10%할인),  마일리지 600원 (5% 적립)
# [국내도서] 그들의 말 혹은 침묵
# 아니 에르노 (지은이), 정혜용 (옮긴이) | 민음사 | 2022년 2월
# 14,000원 → 12,600원 (10%할인),  마일리지 700원 (5% 적립)
# [국내도서] 데뷔 못 하면 죽는 병 걸림 1부 초판 한정 굿즈박스 세트 ㅣ 데뷔 못 하면 죽는 병 걸림 1
# 백덕수 (지은이) | 위시북스(KW북스) | 2022년 12월
# 95,000원 → 85,500원 (10%할인),  마일리지 4,750원 (5% 적립)
# [국내도서] 미움받을 용기 (반양장) ㅣ 미움받을 용기 1
# 기시미 이치로, 고가 후미타케 (지은이), 전경아 (옮긴이), 김정운 (감수) | 인플루엔셜(주) | 2014년 11월
# 14,900원 → 13,410원 (10%할인),  마일리지 740원 (5% 적립)
# [국내도서] 체리새우 : 비밀글입니다 ㅣ 문학동네 청소년 42
# 황영미 (지은이) | 문학동네 | 2019년 1월
# 11,500원 → 10,350원 (10%할인),  마일리지 570원 (5% 적립)
# [국내도서] 정의란 무엇인가
# 마이클 샌델 (지은이), 김명철 (옮긴이), 김선욱 (감수) | 와이즈베리 | 2014년 11월
# 15,000원 → 13,500원 (10%할인),  마일리지 750원 (5% 적립)
# [국내도서] 나는 당신이 행복했으면 좋겠습니다
# 박찬위 (지은이) | 하이스트 | 2021년 11월
# 13,800원 → 12,420원 (10%할인),  마일리지 690원 (5% 적립)
# [국내도서] 어디로 가세요 펀자이씨? ㅣ 펀자이씨툰 1
# 엄유진 (지은이) | 문학동네 | 2022년 9월
# 16,000원 → 14,400원 (10%할인),  마일리지 800원 (5% 적립)
# [국내도서] 부모의 말
# 김종원 (지은이) | 상상아카데미 | 2022년 8월
# 16,800원 → 15,120원 (10%할인),  마일리지 840원 (5% 적립)
# [국내도서] 혼자 공부하는 컴퓨터 구조 + 운영체제
# 강민철 (지은이) | 한빛미디어 | 2022년 8월
# 28,000원 → 25,200원 (10%할인),  마일리지 1,400원 (5% 적립)
# [국내도서] 우리가 빛의 속도로 갈 수 없다면
# 김초엽 (지은이) | 허블 | 2019년 6월
# 14,000원 → 12,600원 (10%할인),  마일리지 700원 (5% 적립)
# [국내도서] 당신이 옳다
# 정혜신 (지은이) | 해냄 | 2018년 10월
# 15,800원 → 14,220원 (10%할인),  마일리지 790원 (5% 적립)
# [국내도서] 2023 선재국어 기출실록 (해설 통합형) 세트 - 전4권 ㅣ 2023 선재국어
# 이선재 (지은이) | 에스티유니타스 | 2022년 9월
# 49,000원 → 44,100원 (10%할인),  마일리지 490원 (1% 적립)
# [국내도서] 이게 다 호르몬 때문이야
# 마쓰무라 게이코 (지은이), 이은혜 (옮긴이) | FIKALIFE(피카라이프) | 2022년 9월
# 15,000원 → 13,500원 (10%할인),  마일리지 750원 (5% 적립)
# [국내도서] 지리의 힘 ㅣ 지리의 힘 1
# 팀 마샬 (지은이), 김미선 (옮긴이) | 사이 | 2016년 8월
# 17,000원 → 15,300원 (10%할인),  마일리지 850원 (5% 적립)
# [국내도서] 마지막 몰입
# 짐 퀵 (지은이), 김미정 (옮긴이) | 비즈니스북스 | 2021년 2월
# 16,800원 → 15,120원 (10%할인),  마일리지 840원 (5% 적립)
# [국내도서] 송사무장의 부동산 경매의 기술
# 송희창 (지은이) | 지혜로 | 2017년 4월
# 16,000원 → 14,400원 (10%할인),  마일리지 800원 (5% 적립)
# [국내도서] 사랑의 기술
# 에리히 프롬 (지은이), 황문수 (옮긴이) | 문예출판사 | 2019년 8월
# 12,000원 → 10,800원 (10%할인),  마일리지 600원 (5% 적립)
# [국내도서] 알고 있다는 착각
# 질리언 테트 (지은이), 문희경 (옮긴이) | 어크로스 | 2022년 8월
# 17,800원 → 16,020원 (10%할인),  마일리지 890원 (5% 적립)
# [국내도서] 신경 청소 혁명
# 구도 치아키 (지은이), 김은혜 (옮긴이) | 비타북스 | 2017년 7월
# 14,000원 → 12,600원 (10%할인),  마일리지 700원 (5% 적립)
# [국내도서] 영어 감정 표현 사전
# 샘 노리스 (지은이), 정병선 (옮긴이) | 길벗이지톡 | 2022년 6월
# 27,000원 → 24,300원 (10%할인),  마일리지 1,350원 (5% 적립)
# [국내도서] 슬로우 미러클 영어 그림책 느리게 100권 읽기의 힘
# 고광윤 (지은이) | 길벗 | 2022년 7월
# 29,800원 → 26,820원 (10%할인),  마일리지 1,490원 (5% 적립)
# [국내도서] 토끼전 : 꾀주머니 배 속에 차고 계수나무에 간 달아 놓고 ㅣ 국어시간에 고전읽기 (휴머니스트) 8
# 장재화 (글), 윤예지 (그림), 전국국어교사모임 (기획) | 휴머니스트 | 2014년 1월
# 13,000원 → 11,700원 (10%할인),  마일리지 650원 (5% 적립)
# [국내도서] 리틀 라이프 1
# 한야 야나기하라 (지은이), 권진아 (옮긴이) | 시공사 | 2016년 6월
# 14,800원 → 13,320원 (10%할인),  마일리지 740원 (5% 적립)
# [국내도서] 타자들의 생태학 ㅣ 월딩 시리즈 1
# 필리프 데스콜라 (지은이), 차은정 (옮긴이) | 포도밭출판사 | 2022년 10월
# 18,000원 → 16,200원 (10%할인),  마일리지 900원 (5% 적립)
# [국내도서] 2023 문동균 한국사 한 권으로 모든 것을 정리하는 빈칸노트
# 문동균 (지은이) | 에스티유니타스 | 2022년 10월
# 12,000원 → 10,800원 (10%할인),  마일리지 120원 (1% 적립)
# [국내도서] 오늘도 고바야시 서점에 갑니다
# 가와카미 데쓰야 (지은이), 송지현 (옮긴이) | 현익출판 | 2022년 8월
# 15,000원 → 13,500원 (10%할인),  마일리지 750원 (5% 적립)
# [국내도서] 2023 전한길 한국사 3.0 기출문제집 - 전2권
# 전한길 (지은이) | 전한길한국사 | 2022년 8월
# 38,000원 → 34,200원 (10%할인),  마일리지 1,900원 (5% 적립)
# [국내도서] 협력의 유전자
# 니컬라 라이하니 (지은이), 김정아 (옮긴이), 장이권 (감수) | 한빛비즈 | 2022년 9월
# 22,000원 → 19,800원 (10%할인),  마일리지 1,100원 (5% 적립)
# [국내도서] 거꾸로 읽는 세계사
# 유시민 (지은이) | 돌베개 | 2021년 10월
# 17,500원 → 15,750원 (10%할인),  마일리지 870원 (5% 적립)
# [국내도서] 스파이 패밀리 2
# 엔도 타츠야 (지은이) | 학산문화사(만화) | 2020년 2월
# 6,000원 → 5,400원 (10%할인),  마일리지 300원 (5% 적립)
# [국내도서] 스파이 패밀리 8
# 엔도 타츠야 (지은이) | 학산문화사(만화) | 2021년 12월
# 6,000원 → 5,400원 (10%할인),  마일리지 300원 (5% 적립)
# [국내도서] 포켓몬스터 썬&문 포켓몬 전국대도감
# 가와시마 준지 (구성), Koji Hayashida (디자인) | 대원키즈 | 2017년 10월
# 9,500원 → 8,550원 (10%할인),  마일리지 470원 (5% 적립)
# [국내도서] 프레임
# 최인철 (지은이) | 21세기북스 | 2021년 3월
# 17,000원 → 15,300원 (10%할인),  마일리지 850원 (5% 적립)
# [국내도서] 법륜 스님의 행복
# 법륜 (지은이), 최승미 (그림) | 나무의마음 | 2016년 1월
# 14,000원 → 12,600원 (10%할인),  마일리지 700원 (5% 적립)
# [국내도서] 나의 히어로 아카데미아 35
# 호리코시 코헤이 (지은이) | 서울미디어코믹스(서울문화사) | 2022년 8월
# 6,000원 → 5,400원 (10%할인),  마일리지 300원 (5% 적립)
# [국내도서] 카구야 님은 고백받고 싶어 24
# 아카사카 아카 (지은이) | 학산문화사(만화) | 2022년 9월
# 6,000원 → 5,400원 (10%할인),  마일리지 300원 (5% 적립)
# [국내도서] 지극히 사적인 네팔
# 수잔 샤키야, 홍성광 (지은이) | 틈새책방 | 2022년 3월
# 16,300원 → 14,670원 (10%할인),  마일리지 810원 (5% 적립)
# [국내도서] 2023 심우철 문법 풀이 전략서
# 심우철 (지은이) | 심슨북스 | 2022년 8월
# 15,000원 → 13,500원 (10%할인),  마일리지 750원 (5% 적립)
# [국내도서] 투자에도 순서가 있다
# 홍춘욱 (지은이) | 알에이치코리아(RHK) | 2022년 9월
# 18,000원 → 16,200원 (10%할인),  마일리지 900원 (5% 적립)
# [국내도서] 전쟁과 약, 기나긴 악연의 역사
# 백승만 (지은이) | 동아시아 | 2022년 9월
# 17,000원 → 15,300원 (10%할인),  마일리지 850원 (5% 적립)
# [국내도서] 사회사상의 역사
# 사카모토 다쓰야 (지은이), 최연희 (옮긴이) | 교유서가 | 2022년 10월
# 33,000원 → 29,700원 (10%할인),  마일리지 990원 (3% 적립)
# ------------------------------------------------------
