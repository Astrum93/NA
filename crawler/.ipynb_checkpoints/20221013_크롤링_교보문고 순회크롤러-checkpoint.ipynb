# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import time
from selenium.webdriver.common.by import By

# %% [markdown]
# ## 순회 크롤러
# - 같은 양식의 페이지를 순회하면서 자료 수집
# - 원 페이지 크롤러 제작 후 완성된 크롤러를 반복문에 삽입
# - 반복의 시작점 판단 중요

# %%
# 금일(22년 10월 13일)기준  45번 반복문을 돌려서
# 다음페이지 xpath를 마지막에 클릭하게 해 주시면 됩니다.
driver = webdriver.Chrome('chromedriver')
#1. n페이지 접근
driver.get('https://product.kyobobook.co.kr/bestseller/online?period=001&page=7')
time.sleep(2)


#5. txt에 저장(추후 다른 셀에서 진행하고 먼저 리스트에 1000개 내외로 저장해주세요.)
# 빈 리스트를 만들어서 제목, 가격, 저자를 전수 저장해줍니다.
title_list=[]
author_list=[]
price_list=[]

for i in range(45):
    time.sleep(2)
    
    #2. 소스코드 긁어오기
    source = driver.page_source
    
    #3. 파싱
    parsed_source = BeautifulSoup(source, "html.parser")
    
    #4. 원하는 데이터 추출
    
    ##############################################################################
    # 전체 코드에서 span태그이면서 클래스속성이 prod_name인 태그만 가져와 저장하기
    ####################### 제목 긁어오기 ########################################    
    span_title_list= parsed_source.find_all("span", class_="prod_name")
    for title in span_title_list:
        title_list.append(title.text.replace(",", "ͺ"))
    
    #############################################################################
    # 전체 코드에서 span태그이면서 클래스속성이 prod_author인 태그만 가져와 저장하기
    ########################저자 긁어오기 #######################################
    span_author_list= parsed_source.find_all("span", class_="prod_author")
    for author in span_author_list:
        author_list.append(author.text.split(" ·")[0])
    
    ###########################################################################
    # 전체 코드에서 span태그이면서 클래스속성이 price인 태그만 가져와 저장하기
    ########################금액 긁어오기 #######################################
    span_price_list= parsed_source.find_all("span", class_="price")
    for price in span_price_list:
        price_list.append(price.text)
    
    # 다음 페이지
    driver.find_element(By.XPATH, '//*[@id="tabRoot"]/div[2]/div[1]/button[2]').click()
    

        
driver.close()

# %%
title_list
# Out:
# ['트렌드 코리아 2023',
#  '사랑은 그렇게 하는 것이 아니다',
#  '엄마의 말하기 연습(20만부 기념 스페셜 에디션)',
#  '반짝이는 하루ͺ 그게 오늘이야',
#  '하얼빈',
#  '세상에서 가장 쉬운 본질육아',
#  '아버지의 해방일지',
#  '불편한 편의점 2',
#  '2022 하반기 에듀윌 취업 온라인 SKCT SK그룹 종합역량검사 통합 기본서',
#  '역행자',
#  '잘될 수밖에 없는 너에게',
#  '바자(BAZAAR)(2022년 11월호)',
#  '바자(BAZAAR)(2022년 11월호)(B형)',
#  '나는 나를 바꾸기로 했다',
#  '불편한 편의점(40만부 기념 벚꽃 에디션)',
#  '부의 치트키',
#  '2022 하반기 해커스 GSAT 삼성직무적성검사 실전모의고사 8회분(수리논리/추리)',
#  '올리버쌤의 미국식 아이 영어 습관 365',
#  '마흔에 읽는 니체',
#  '바자(BAZAAR)(2022년 11월호)(C형)',
#  '작은 땅의 야수들',
#  '단순한 열정',
#  '심리학이 분노에 답하다',
#  '파친코 2',
#  '파친코 1',
#  '원씽(The One Thing)(리커버 특별판)',
#  '이 책은 돈 버는 법에 관한 이야기',
#  '그릿(100쇄 기념 리커버 에디션)',
#  '부자 아빠 가난한 아빠 1(20주년 특별 기념판)',
#  '생각이 많아 우울한 걸까ͺ 우울해서 생각이 많은 걸까?',
#  'The Scent of PAGE : 디퓨저 200ml',
#  'SQL 자격검정 실전문제',
#  '트렌드 코리아 2023',
#  '이토록 평범한 미래',
#  '퀀트 투자 무작정 따라하기',
#  '사람을 얻는 지혜',
#  'The Scent of PAGE : 룸스프레이 60ml',
#  'The Scent of PAGE : 디퓨저 리필액 250ml',
#  '2022 해커스 SKCT SK그룹 종합역량검사 봉투모의고사',
#  '데일 카네기 인간관계론',
#  '돈의 속성(200쇄 리커버에디션)',
#  '데이터는 어떻게 인생의 무기가 되는가',
#  '혼자서 종이우산을 쓰고 가다',
#  '저스트. 킵. 바잉.',
#  '믹스(Mix)',
#  '너의 이름을 사랑이라 부른다',
#  '해외설교(올랜도)',
#  '오십의 주역공부',
#  '세상의 마지막 기차역',
#  '해커스 GSAT 삼성직무적성검사 Final 봉투모의고사 4회분',
#  '2022 큰별쌤 최태성의 별별한국사 기출 500제 한국사능력검정시험 심화',
#  '하버드대생 공부법은 당신과 다르다',
#  '해커스 토익 기출보카 TOEIC VOCA(토익보카) 단어장',
#  'ETS 토익 정기시험 기출문제집 1000 Vol 3 LISTENING(리스닝)',
#  '세상이 궁금해서 일찍 나왔니?',
#  '헤어질 결심 스토리보드북',
#  '부의 추월차선(10주년 스페셜 에디션)',
#  'ETS 토익 정기시험 기출문제집 1000 Vol 3 READING(리딩)',
#  '나는 당신이 행복했으면 좋겠습니다',
#  '최소한의 이웃',
#  '기분을 관리하면 인생이 관리된다',
#  '2022 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1ͺ 2ͺ 3급)(상)',
#  'EBS 만점마무리 봉투모의고사 국어영역 3회분(2022)(2023 수능대비)',
#  '심리학이 조조에게 말하다 1',
#  '엉뚱소심 유령 탐정단 1: 도서관 유령 소동',
#  '2022 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1ͺ 2ͺ 3급)(하)',
#  'EBS 만점마무리 봉투모의고사 영어영역 3회분(2022)(2023 수능대비)',
#  '타이탄의 도구들(블랙 에디션)',
#  '이기적 유전자(40주년 기념판)',
#  '4영리에 대하여 들어 보셨습니까(소책자)',
#  '빠르게 실패하기',
#  '거의 모든 행동 표현의 영어',
#  '아주 작은 습관의 힘',
#  '방구석 뮤지컬',
#  '나의 투자는 새벽 4시에 시작된다',
#  '10배의 법칙',
#  '위로의 미술관',
#  '2022 하반기 All-New SKCT SK그룹 온라인 최신기출유형+모의고사 5회+무료SK특강',
#  '언어를 디자인하라',
#  '클루지',
#  'EBS 고난도 시크릿X 봉투모의고사 영어영역(2022)(2023 수능 대비)',
#  '나는 오래된 거리처럼 너를 사랑하고',
#  '어서 오세요ͺ 이야기 수학 클럽에',
#  'EBS Final 실전모의고사 고등 영어영역(2022)(2023 수능대비)',
#  '어서 오세요ͺ 휴남동 서점입니다 (여름 숲 에디션)',
#  '두레문학(2022년 하반기 제32호)',
#  '그리고 행복하다는 소식을 들었습니다',
#  '예쁘게 말하는 네가 좋다',
#  '가녀장의 시대',
#  '기도수첩(Remnant)(2022년 11월호)',
#  '흔한남매의 흔한 호기심 7',
#  '우리는 어디서 살아야 하는가',
#  '2022 해커스 GSAT 삼성직무적성검사 통합 기본서 최신기출유형+실전모의고사',
#  '외사랑',
#  '어떻게 말해줘야 할까(60만 부 기념 한정판 리커버)',
#  '2022 하반기 에듀윌 취업 온라인 GSAT 삼성직무적성검사 실전 봉투모의고사 10회',
#  '작별인사(밤하늘 에디션)',
#  '오싹오싹 크레용!',
#  '진짜 쓰는 실무 엑셀',
#  '마이클 모부신 운과 실력의 성공 방정식',
#  '교보문고 시그니처 독서대(월넛)',
#  '부의 인문학(20만부 기념 개정증보판)',
#  '좋은 불평등',
#  '혼자 공부하는 파이썬',
#  '아몬드(100만 부 기념 특별판)',
#  'EBS Final 실전모의고사 고등 국어영역(2022)(2023 수능대비)',
#  '쎈 중등 수학 2-2(2022)',
#  '나는 나의 밤을 떠나지 않는다',
#  '엄마의 말 연습',
#  '대발이는 벚꽃을 좋아해',
#  '변화하는 세계 질서',
#  '2022 ADsP 데이터 분석 준전문가',
#  '365 부모 말하기 연습 일력',
#  '마지막 몰입: 나를 넘어서는 힘',
#  '문장과 순간',
#  '설민석의 한국사 대모험 22',
#  '역설계',
#  '다이어트 사이언스(2022)',
#  '2022 에듀윌 취업 SKCT SK그룹 종합역량검사 통합 기본서 최신기출유형+실전ㆍ직무모의고사 5회',
#  '데일 카네기 자기관리론(1948년 초판 완역본)',
#  '부자의 그릇',
#  'EBS 만점마무리 봉투모의고사 Red Edition(2022)(2023 수능 대비)',
#  '테라피스트',
#  '2023 써니 행정법총론 기출문제집',
#  '우리의 정원',
#  '물고기는 존재하지 않는다',
#  '돈ͺ 뜨겁게 사랑하고 차갑게 다루어라',
#  '능률 VOCA 어원편',
#  '순례 주택',
#  '긴긴밤',
#  'EBS 만점마무리 봉투모의고사 수학영역 3회분(2022)(2023 수능대비)',
#  '백년허리 2: 치료편',
#  '단순한 열정',
#  '무조건 수익 내는 실전 부동산 경매',
#  '벌거벗은 한국사: 인물편',
#  '오은영의 화해',
#  '마음세탁소',
#  '오투 중등 과학 3-2(2022)',
#  '다정한 것이 살아남는다',
#  '하얼빈',
#  '컬러의 방',
#  '사로잡는 얼굴들',
#  '참 괜찮은 태도',
#  '내 일로 건너가는 법',
#  '수학은 어떻게 문명을 만들었는가',
#  'EBS 만점마무리 봉투모의고사 사회탐구영역 생활과 윤리 5회분(2022)(2023 수능대비)',
#  'EBS 만점마무리 봉투모의고사 사회탐구영역 사회 문화 5회분(2022)(2023 수능대비)',
#  '월급쟁이 부자로 은퇴하라(10만 부 돌파 기념 증보판)',
#  'EBS 수능완성 영어영역 영어(2022)(2023 수능대비)',
#  '2022 해커스 파생상품투자권유자문인력 최종핵심정리문제집+실전모의고사 2회분',
#  '오십에 읽는 논어(교보문고 특별판 리커버)',
#  '삐뽀삐뽀 119 이유식',
#  '침묵의 봄',
#  '레버리지',
#  '흔한남매 수수께끼 어드벤처 1',
#  '세월',
#  '누구에게도 상처받을 필요는 없다',
#  'EBS 수능특강 영어영역 영어(2022)(2023 수능대비)',
#  '세계미래보고서 2023',
#  '마지막 이야기 전달자',
#  '한국 교회 트렌드 2023',
#  '다니엘 핑크 후회의 재발견',
#  '어느 날ͺ 내 죽음에 네가 들어왔다',
#  '오늘 밤ͺ 세계에서 이 사랑이 사라진다 해도',
#  '지리의 힘',
#  '예비 매3비 매일 지문 3개씩 푸는 비문학 독서 기출',
#  '사피엔스',
#  '계절의 위로',
#  '뇌ͺ 욕망의 비밀을 풀다',
#  '김승옥문학상 수상작품집(2022)',
#  '2022 단기 합격 해커스공기업 NCS 통합 기본서 직업기초능력평가+직무수행능력평가',
#  '100발100중 중등 영어 3-2 기말고사 기출문제집(동아 윤정미)(2022)',
#  '스틱',
#  'MAXIDENT [GO VER] [한정반]',
#  '꽃을 보듯 너를 본다',
#  '2022 하반기 All-New 기출이 답이다 SKCT SK그룹 온라인 종합역량검사+무료SK특강',
#  '2022 하반기 렛유인 GSAT 삼성직무적성검사 Final 봉투모의고사',
#  '신인류가 몰려온다',
#  'EBS 고난도 시크릿X 봉투모의고사 국어영역(2022)(2023 수능 대비)',
#  '흔한남매 11',
#  '인플레이션에서 살아남기',
#  '한국보훈복지의료공단 보훈병원 필기시험 실력평가 모의고사',
#  '큰별쌤 최태성의 별별한국사 7일의 기적 한국사능력검정시험 심화(1ͺ 2ͺ 3급)',
#  '쎈 중등 수학 3-2(2022)',
#  '매3비 매일 지문 3개씩 푸는 비문학 독서 수능 기출(2022)(2023 수능대비)',
#  '이어령의 마지막 수업',
#  '당신의 뇌는 최적화를 원한다',
#  '욕망의 진화',
#  '중학영문법 3800제 1학년(2023)',
#  '아홉 살 마음 사전',
#  'Wonder 영화 <원더> 원작 소설 미국판',
#  '장사의 신',
#  '내가 알고 있는 걸 당신도 알게 된다면(리커버 에디션)',
#  '대한민국 부동산 부의 역사',
#  '눈물 한 방울',
#  '천일문 기본 Basic 1001 Sentences',
#  '백년허리 1: 진단편',
#  '아버지의 해방일지',
#  '부자 아빠 가난한 아빠. 1(20주년 특별 기념판)',
#  'ADHD 우리 아이 어떻게 키워야 할까',
#  '어린이를 위한 역사의 쓸모 2: 고려 시대 - 조선 전기',
#  '2022 하반기 고시넷 NCS 지역농협 6급 오픈봉투모의고사',
#  '어린이를 위한 역사의 쓸모 1: 선사시대~남북국 시대',
#  'EBS 만점마무리 봉투모의고사 한국사영역 5회분(2022)(2023 수능대비)',
#  '멘탈을 바꿔야 인생이 바뀐다',
#  '해커스 OPIc 오픽 START Intermediate 공략',
#  '소크라테스 익스프레스',
#  '달러구트 꿈 백화점(레인보우 에디션)',
#  '정리하는 뇌',
#  '인간 실격',
#  'The Scent of PAGE : 차량용 방향제',
#  '위라클(WERACLE)',
#  '한반도에 지저스 웨이브가 온다',
#  '미움받을 용기',
#  '코스모스',
#  '이것은 작은 브랜드를 위한 책',
#  '사건',
#  '미술관에 간 바이올리니스트',
#  '매거진 B(Magazine B) No.91: Hawaii(한글판)',
#  '예민한 아이를 위한 부모 수업',
#  '미술관을 빌려드립니다: 프랑스',
#  '운명을 바꾸는 부동산 투자 수업(11만 부 기념 바이블 에디션)',
#  '위대한 과학 고전 30권을 1권으로 읽는 책',
#  '해커스 국민건강보험공단 NCS+법률 봉투모의고사 5+4회',
#  '대출의 마법',
#  '2022 하반기 에듀윌 공기업 국민건강보험공단 NCS+법률 봉투모의고사 4+3회+법률 100제',
#  '헤어질 결심 각본',
#  '2022 해커스 투자자산운용사 최종핵심정리문제집+실전모의고사 3회분',
#  '마음의 법칙',
#  '오투 중등 과학 2-2(2022)',
#  '세계를 건너 너에게 갈게',
#  '마법에서 과학으로: 자석과 스핀트로닉스',
#  '돈의 심리학(10만 부 돌파 기념 골드 에디션)',
#  '서찰을 전하는 아이',
#  '총 균 쇠',
#  '넛지(파이널 에디션)',
#  '백년운동',
#  '중학영문법 3800제 2학년(2023)',
#  '데미안',
#  '2023 부산광역시교육청 교육공무직원 소양평가 인성검사 3회+실전모의고사 7회+면접+무료공무직특강',
#  '빈 옷장',
#  '올드패션 베이킹북',
#  '오버로드 15: 하프엘프 신인(상)',
#  '책과 우연들',
#  '딥 타임',
#  '초역 니체의 말',
#  '재수사 1',
#  '오늘 밤ͺ 세계에서 이 눈물이 사라진다 해도',
#  '계속 가보겠습니다',
#  '튜브',
#  '바로 쓰는 영어',
#  '2023 해커스공무원 신민숙 쉬운국어 어법 필기노트(9급 공무원ͺ 7급 공무원)',
#  '비상식적 성공 법칙',
#  'EBS Final 실전모의고사 고등 수학영역(2022)(2023 수능대비)',
#  '해커스 토익 RC 리딩(Reading) 토익 기본서',
#  '해커스 보카(Hackers Vocabulary)',
#  '지구 끝의 온실(여름 에디션)',
#  '한끝 중등 역사 2-2(2023)',
#  '최상위 수학 초등 5-2(2022)',
#  '숲 속에서',
#  '삶의 격',
#  '시크릿',
#  '2ND MINI ALBUM [ANTIFRAGILE] [WEVERSE ALBUMS VER]',
#  '몬스터 차일드',
#  '체리새우: 비밀글입니다',
#  '개념원리 고등 수학(상)(2022)',
#  '위풍당당 여우 꼬리 3: 핼러윈과 어둠 숨바꼭질',
#  '소설 보다: 가을 2022',
#  '반도체 애널리스트의 리서치 습관',
#  '재수사 2',
#  '디딤돌 초등수학 기본+응용 5-1(2023)',
#  'EEA: English for Everyday Activities(한글판)',
#  '그리스도인의 확신',
#  '세상에서 가장 쉬운 본질육아',
#  '마흔에 읽는 니체',
#  '원씽(The One Thing)(리커버 특별판)',
#  '사람을 얻는 지혜',
#  '사랑받는 막내는 처음이라. 1',
#  '구궐황도. 4',
#  '구궐황도. 2',
#  '구궐황도. 3',
#  '영원한 계약 43화 (42화)',
#  '슬픔이 택배로 왔다',
#  '부동산 경매로 1년 만에 꼬마빌딩주 되다',
#  '이해원 모의고사 시즌3(2022)(2023 수능대비)',
#  '리얼 교토: 고베 나라(2022~2023)',
#  'EBS 고난도 시크릿X 봉투모의고사 수학영역(2022)(2023 수능 대비)',
#  '2023 황변과 함께하는 로스쿨면접 Q (1ͺ2ͺ3) 세트',
#  '채사장의 지대넓얕 4: 보이지 않는 손',
#  '나의 아름다운 할머니',
#  '푸른 사자 와니니 4: 작은 코뿔소 파투',
#  '벌거벗은 세계사: 전쟁편',
#  '패턴국어 중학문학 현대시',
#  '세계사를 바꾼 커피 이야기',
#  '28시간에 끝내는 토익스피킹 스타트',
#  'EBS 수능완성 국어영역 독서·문학·화법과 작문(2022)(2023 수능대비)',
#  '내가 틀릴 수도 있습니다',
#  '2022 해커스 NCS 지역농협 6급 통합 기본서 인적성 및 직무능력평가',
#  '큰별쌤 최태성의 별별한국사 시대별 기출문제집 한국사능력검정시험 심화(1ͺ2ͺ3급)',
#  '경제기사 궁금증 300문 300답(2022)',
#  '아이주도 이유식 유아식 매뉴얼 세트',
#  '발타자르 그라시안의 인생 수업',
#  '영어 회화의 결정적 단어들',
#  '푸른 사자 와니니',
#  '경제지표 정독법',
#  '알밤 소풍',
#  '그림의 힘(프레더릭 레이턴 리커버 에디션)',
#  '왜 리더인가',
#  '고등 어법끝 Start',
#  '마법천자문 54: 처음으로 찾아내다! 발견',
#  '문재인의 위로 필사',
#  '남자의 자리',
#  '훌훌',
#  '쎈 중등 수학 2-1(2022)',
#  'Clean Code(클린 코드)',
#  '호밀밭의 파수꾼',
#  '불편한 편의점',
#  '구궐황도. 11',
#  '구궐황도. 5',
#  '새벽의 연화. 37',
#  '아이주도 이유식 유아식 매뉴얼 세트',
#  '발타자르 그라시안의 인생 수업',
#  '영어 회화의 결정적 단어들',
#  '푸른 사자 와니니',
#  '경제지표 정독법',
#  '알밤 소풍',
#  '그림의 힘(프레더릭 레이턴 리커버 에디션)',
#  '왜 리더인가',
#  '고등 어법끝 Start',
#  '마법천자문 54: 처음으로 찾아내다! 발견',
#  '문재인의 위로 필사',
#  '남자의 자리',
#  '훌훌',
#  '쎈 중등 수학 2-1(2022)',
#  'Clean Code(클린 코드)',
#  '호밀밭의 파수꾼',
#  '불편한 편의점',
#  '구궐황도. 11',
#  '구궐황도. 5',
#  '새벽의 연화. 37',
#  '라이트쎈 중등 수학 1-1(2022)',
#  '벌거벗은 세계사: 사건편',
#  '나는 장사의 신이다',
#  '흔한남매 9',
#  '디딤돌 초등 수학 응용 5-2(2022)',
#  '쎈 고등 수학(하)(2022)',
#  '해커스 OPIc 오픽 Advanced 공략',
#  '월가의 영웅',
#  '미드나잇 라이브러리(1주년 스페셜 에디션)',
#  '토익 단기공략 750+(LC+RC)',
#  '엄마 나는 자라고 있어요',
#  'EBS 윤혜정의 나비효과 입문편(2022)',
#  '유럽 도시 기행 1',
#  '부끄러움',
#  '경매 권리분석 이렇게 쉬웠어?',
#  '튼이 이유식',
#  '오싹오싹 팬티!',
#  'ETS 토익 기출 VOCA 출제기관 공식수험서',
#  '채근담 필사노트',
#  '송사무장의 부동산 경매의 기술',
#  'Give and Take(기브앤테이크)',
#  '기억 전달자',
#  '순전한 기독교',
#  '신기한 맛 도깨비식당 1',
#  'When You Trap a Tiger (2021 Newbery Winner) 2021 뉴베리 수상작ͺ < 호랑이를 덫에 가두면 > 원서',
#  '채사장의 지대넓얕 3: 폭력의 시대',
#  '싱글맘 부동산 경매로 홀로서기',
#  '지적 대화를 위한 넓고 얕은 지식: 제로 편',
#  '도시인의 월든',
#  '5년 후 나에게 Q&A a Day(2022 오리지널)',
#  '어른의 문답법(리커버 스페셜 에디션)',
#  '쎈 중등 수학 1-2(2022)',
#  '맨발로 걸어라: 돈이 안 들고 부작용이 없는 최고의 자연치유요법',
#  '포켓몬 한글쓰기 100일 마스터',
#  '낙엽 스낵',
#  '유럽 도시 기행 2',
#  '원피스 102: 천왕산',
#  '마더텅 수능기출문제집 영어 독해(2022)(2023 대비)',
#  '해커스 토익 실전 1200제 RC Reading 리딩',
#  '밝은 밤',
#  '생각하라 그리고 부자가 되어라',
#  '파친코 2',
#  '그릿(100쇄 기념 리커버 에디션)',
#  '구궐황도. 9',
#  '소꿉친구의 장난 - 한뼘 로맨스 컬렉션 491',
#  '불순한 스캔들. 외전',
#  '디지털 트렌드 2023',
#  '된다! 실무 엑셀 파워포인트 워드&한글',
#  '라이프 트렌드 2023',
#  '오늘 좀 그대가 보고 싶네요',
#  '커픽처스 커피 레시피 101',
#  '이해찬 회고록',
#  '설민석의 세계사 대모험 14',
#  '원펀맨(One Punch Man) 26',
#  '게으른 완벽주의자를 위한 심리학',
#  '당신에게 좋은 소식을 전해줄게요',
#  '푸른 사자 와니니 5: 초원의 바람',
#  '2022 하반기 All-New SKCT SK그룹 온라인 최신기출유형+모의고사 5회+무료SK특강',
#  '세계시민이 된 실험경제반 아이들',
#  '건강의 뇌과학',
#  'ETS 토익 단기공략 850+(LC+RC)',
#  '에듀윌 공기업 행과연형(행동과학연구소) NCS 봉투모의고사 4회',
#  '최재천의 공부',
#  'EBS Final 실전모의고사 고등 사회탐구영역 생활과 윤리(2022)(2023 수능대비)',
#  'EBS Final 실전모의고사 고등 사회탐구영역 사회ㆍ문화(2022)(2023 수능대비)',
#  '최강의 실험경제반 아이들',
#  '에이든 국내여행 가이드북(2022-2023)',
#  '도파민네이션',
#  '보도 섀퍼의 이기는 습관',
#  '카사노바 호텔',
#  '쎈 초등 수학 3-2(2022)',
#  '벌거벗은 세계사: 인물편',
#  '픽사 스토리텔링',
#  '해커스 일본어 첫걸음: 기초20일 독학 완성!',
#  'EBS 수능특강 국어영역 독서(2022)(2023 수능대비)',
#  '2022 혼잡(JOB) 농협은행 6급(5급 공통) 기출분석+실전모의고사 3회분',
#  '마더텅 수능기출 모의고사 30회 영어 영역(2022)(2023 수능대비)',
#  'Grammar Inside(그래머 인사이드) Level 1',
#  '한 권으로 끝내는 해커스 토익 700+ (LC+RC+VOCA)',
#  '윤혜정의 개념의 나비효과 수능국어개념(2022)(2023 수능대비)',
#  '매3문: 매일 지문 3개씩 푸는 문학 수능 기출(2022)(2023 대비)',
#  '마더텅 수능기출문제집 국어 언어와 매체(2022)(2023 대비)',
#  '마더텅 수능기출문제집 고등 영어 듣기(2022)(2023 대비)',
#  '영어 필사 100일의 기적',
#  '달러구트 꿈 백화점 2(레인보우 에디션)',
#  '쎈 중등 수학 1-1(2022)',
#  '왜 일하는가',
#  '화성에서 온 남자 금성에서 온 여자',
#  'Do it! HTML+CSS+자바스크립트 웹 표준의 정석',
#  '공정하다는 착각',
#  '일품 중등 수학 3(하) 359제(2022)',
#  '최상위 수학 초등 6-2(2022)',
#  '가재가 노래하는 곳',
#  '나는 소망한다 내게 금지된 것을',
#  '삐뽀삐뽀 119 소아과',
#  '부자 아빠의 투자 가이드',
#  '동호문답',
#  "Charlotte's Web (Newbery Honor Bookͺ 1953) <샬롯의 거미줄> 원서ͺ 미국판",
#  '개념원리 고등 수학(하)(2022)',
#  '절세 상식사전(2022)',
#  '채식주의자',
#  '만복이네 떡집',
#  '파이썬과 40개의 작품들',
#  '채사장의 지대넓얕 2: 자본이라는 신',
#  '가짜 모범생',
#  '채사장의 지대넓얕 1: 권력의 탄생',
#  '마플 시너지 고등 수학(하)(2022)',
#  '불순한 스캔들. 1',
#  '그 가이드가 집착광공의 품에서 벗어나는 방법. 7(완결)',
#  'EBS 만점왕 초등 수학 1-2(2022)',
#  '디지털 트랜스포메이션',
#  '아홉살 인생',
#  '나는 팀장답게 일하고 있는가',
#  '신경 청소 혁명',
#  'The Scent of PAGE : 종이방향제',
#  '잘 파는 사람은 이렇게 팝니다',
#  '매일매일 행복해',
#  '읽으면서 바로 써먹는 어린이 수수께끼: 공포 특급',
#  '너무 잘하려고 애쓰지 마라',
#  '개념원리 중학 수학 1-2(2022)',
#  '쎈 초등 수학 4-2(2022)',
#  '2022 해커스 무역영어 1급 4주 완성 이론+기출+모의고사 11회분',
#  '파친코 1',
#  '역행자',
#  '그 가이드가 집착광공의 품에서 벗어나는 방법. 2',
#  '구궐황도. 7',
#  '구궐황도. 10',
#  '법련 10월호(2022년)',
#  '황태녀의 기사',
#  '클라우드 머니',
#  '사진의 용도',
#  '엉뚱소심 유령 탐정단 2: 다락방 유령 사건',
#  '반도체 삼국지',
#  '오늘도 쓰담쓰담',
#  '우리는 모두 생존자입니다',
#  '브랜드 기획자의 시선',
#  '더 위험한 미래가 온다',
#  '워드마스터 중등 실력',
#  '의사 어벤저스 9: 피부 질환ͺ 부드럽게 화해하라!',
#  '넘버스 스틱!',
#  '조정민의 답답답',
#  '아틀라스 한국사',
#  'High Top(하이탑) 중학교 과학3(2023)',
#  '쓰면 쓸수록 돈이 모이는 가계부(2023)',
#  '2022 투자자산운용사 한권으로 끝내기 ver 8.0',
#  '이것이 금융논술이다 7.0: 금융기관ͺ 금융공기업편',
#  '2022 All-New NH농협은행 5급 필기전형 최신기출유형+모의고사 6회+무료NCS특강',
#  '2022 해커스 20대기업 인적성 최신기출유형+실전문제 통합 기본서',
#  '임신 출산 육아 대백과(2022~2023)',
#  '2023 해커스 김종수 로스쿨 면접 200주제: 기본편+심화편+기출해설&자소서편',
#  '2023 해커스공무원 이중석 맵핑 한국사 올인원 블랭크노트',
#  '영어 감정 표현 사전',
#  'EBS 만점왕 초등 수학 3-2(2022)',
#  'EBS 수능완성 국어영역 독서·문학·언어와 매체(2022)(2023 수능대비)',
#  '흔한남매 10',
#  '체크체크 교과서편 국어 중 3-2(천재 박영목)(2022)',
#  '당신은 결국 무엇이든 해내는 사람',
#  '지극히 사적인 네팔',
#  '집착',
#  '2022 고시넷 NCS 지역농협 6급 기본서 인적성 및 직무능력평가',
#  '늙는다는 착각',
#  '오백 년째 열다섯',
#  'EBS 수능특강 국어영역 문학(2022)(2023 수능대비)',
#  '해커스 토익 LC 리스닝(Listening) 토익 기본서',
#  '강성태 66일 영어회화',
#  '마더텅 수능기출문제집 국어 독서(2022)(2023 대비)',
#  '마더텅 수능기출문제집 국어 문학(2022)(2023 수능대비)',
#  '쎈 초등 수학 5-2(2022)',
#  '자이스토리 영어 독해 기본(2022)',
#  '쎈 고등 수학1(2022)',
#  '모든 것은 기본에서 시작한다',
#  '해커스 토익 실전 1000제 1 LC Listening(리스닝) 문제집',
#  '잘했고 잘하고 있고 잘 될 것이다(20만 부 기념 개정판)',
#  '엔드 오브 타임',
#  '마음이 흐르는 대로',
#  '시선으로부터ͺ',
#  '인스타 브레인',
#  '칵테일ͺ 러브ͺ 좀비 (리커버)',
#  '지적 대화를 위한 넓고 얕은 지식 1',
#  '이방인',
#  'Pachinko (National Book Award Finalist) 애플TV+ 파친코 원작',
#  '여름은 오래 그곳에 남아',
#  '정의란 무엇인가',
#  '모순',
#  '나미야 잡화점의 기적',
#  '오즈의 마법사',
#  '우리글 바로쓰기 1',
#  '빠작 초등 3~4학년 국어 비문학 독해 3단계',
#  '다시ͺ 수학이 필요한 순간',
#  '가방 들어주는 아이',
#  'The Scent of PAGE : 차량용 방향제 리필',
#  '당신에게 위로가 되었으면 좋겠습니다',
#  '눈물의 무게',
#  '두 번째 지구는 없다',
#  '스크루테이프의 편지',
#  '구덩이',
#  '금쪽이들의 진짜 마음속',
#  '그냥 하지 말라',
#  '100발100중 중등 수학 2-2 기말고사 기출문제집(2022)',
#  '순서 파괴',
#  '더우면 벗으면 되지',
#  '지적 대화를 위한 넓고 얕은 지식 2',
#  '마플시너지 고등 수학2 내신대비 문제집(2022)',
#  '초등 경선식 영단어 5-6학년&중학대비',
#  '뿌리깊은 초등국어 독해력 1단계(초등 1-2학년 대상)',
#  '와인 사피엔스',
#  '수상한 지하실',
#  '마더텅 100% 실전대비 MP3 중학영어듣기 24회 모의고사 2학년(2023)',
#  '매일 만들어 먹고 싶은 식사샐러드',
#  '대도시의 사랑법',
#  '개념원리 중학 수학 2-1(2023)',
#  '마음이 흔들려서ͺ 마흔인 걸 알았다',
#  '밥 프록터 부의 확신',
#  'EBS 만점왕 초등 수학 5-2(2022)',
#  '여행영어 10분의 기적',
#  '흔한남매 과학탐험대 3: 인체',
#  '천일문 기본 문제집(Training Book)',
#  'Do it! 점프 투 파이썬',
#  '떨림과 울림',
#  '당신이 옳다',
#  "Escape from Mr. Lemoncello's Library",
#  'Out of My Mind',
#  '차라투스트라는 이렇게 말했다',
#  '10배의 법칙',
#  'The Scent of PAGE : 미니 룸스프레이 15ml (개선판)',
#  '문제적 상속녀. 2',
#  '구궐황도. 6',
#  '너만 모르는 애정',
#  '카이스트 미래전략(2023)',
#  '에듀윌 공기업 한국수력원자력 ALL NCS 최최종 봉투모의고사',
#  '코딩 자율학습 나도코딩의 C 언어 입문',
#  '2022 투자자산운용사 실제유형 모의고사 + 특별부록 PASSCODE Premium ver 1.0',
#  '이게 다 호르몬 때문이야',
#  '처음 읽는 그리스 로마 신화 8: 영웅 헤라클레스',
#  '엄마 어디 있지?',
#  '쿠키런 서바이벌 대작전 44: 새로운 모험의 시작 편',
#  '쿠키런 어드벤처 53: 비밀의 땅속 지하 세계 편',
#  '이코노미스트 홍춘욱 투자에도 순서가 있다',
#  '개념원리 중학 수학 3-1(2023)',
#  '모바일 미래보고서 2023',
#  '사물의 소멸',
#  '프렌즈 스페인 포르투갈(2022~2023)',
#  '열혈강호 86',
#  '해파리 버스',
#  '2022 신용한 지방자치론 실전모의고사',
#  '쇳밥일지',
#  '트로피컬 나이트',
#  '가짜 노동',
#  '숫자로 일하는 법',
#  '일본어 무작정 따라하기(완전판)',
#  '2023 소방안전관리자 2급 기본문제+5개년 기출문제',
#  '슬로우 미러클 영어 그림책 느리게 100권 읽기의 힘',
#  '이해원 모의고사 시즌2(2022)(2023 수능대비)',
#  '에듀윌 공기업 최신판 인국공 인천국제공항공사 NCS 봉투모의고사 3+1회',
#  '2022 하반기 에듀윌 취업 온라인 GSAT 삼성직무적성검사 통합 기본서',
#  '도쿄 큐레이션',
#  '개념원리 RPM 고등 수학(하)(2022)',
#  '해커스 토익 실전 1000제 3 RC Reading(리딩) 토익문제집',
#  '기획의 정석(20만부 기념 특별판)',
#  '윌리엄 오닐 최고의 주식 최적의 타이밍 성공투자 스토리',
#  '이해원 모의고사 시즌1(2022)(2023 수능대비)(봉투)',
#  '2022 해커스 서울교통공사 NCS+전공 봉투모의고사 5+1회',
#  '한 컷 한국사',
#  '10일 만에 끝내는 해커스 토익스피킹(토스)',
#  '2022 에듀윌 공인중개사 2차 실전모의고사 10회분',
#  '2022 에듀윌 공인중개사 1차 실전모의고사 10회분',
#  'EBS 수능완성 수학영역 수학1·수학2·미적분(2022)(2023 수능대비)',
#  '어른의 문해력',
#  '너의 하늘을 보아',
#  '2022 에듀윌 공기업 서울교통공사 NCS+전공 봉투모의고사 5+1회',
#  '2022 청소년상담사 2급ㆍ3급 2차 면접대비',
#  '파이썬 머신러닝 완벽 가이드',
#  'EBS Final 실전모의고사 고등 과학탐구영역 지구과학1(2022)(2023 수능대비)',
#  '지리의 힘 2',
#  '개념원리 RPM 알피엠 중학 수학 1-2(2022)',
#  '개념원리 중학 수학 2-2(2022)',
#  '김헌의 그리스 로마 신화',
#  '2022 위포트 국민건강보험공단 NCS 실전 봉투모의고사4+3회(NCS+ 법률)',
#  '그래머 게이트웨이 베이직: 초보를 위한 기초 영문법(Grammar Gateway Basic)',
#  '2022 에듀윌 답만보는 운전면허 필기 1종·2종 공통',
#  'EBS 수능특강 한국사영역 한국사(2022)(2023 수능대비)',
#  'EBS 수능특강 과학탐구영역 지구과학1(2022)(2023 수능대비)',
#  '마더텅 수능기출 모의고사 35회 사회 · 문화(2022)(2023 수능대비)',
#  '2022 에듀윌 한국사능력검정시험 2주끝장 심화',
#  '자이스토리 고등 영어 독해 실전(2022)(2023 수능대비)',
#  '방구석 미술관',
#  '마더텅 수능기출문제집 고등 사회·문화(2022)(2023 수능대비)',
#  '마더텅 수능기출문제집 생명과학1(2022)(2023 수능대비)',
#  '쎈 초등 수학 6-2(2022)',
#  '웰씽킹(WEALTHINKING)',
#  '제로 투 원(리커버 에디션)',
#  '작별하지 않는다',
#  '해커스 토익 실전 1000제 1 RC Reading(리딩) 문제집',
#  '100발100중 중등 영어 3-2 기말고사 기출문제집(천재 정사열)(2022)',
#  '100발100중 중등 영어 3-2 기말고사 기출문제집(능률 김성곤)(2022)',
#  '100발100중 중등 수학 3-2 기말고사 기출문제집(2022)',
#  '이토록 뜻밖의 뇌과학',
#  '쎈 중등 수학 3-1(2022)',
#  '죽이고 싶은 아이',
#  '나는 주식 대신 달러를 산다',
#  '좋은 기업을 넘어 위대한 기업으로(20주년 뉴에디션)',
#  '무조건 팔리는 카피 단어장',
#  'RADIX LISTENING for the TOEFL iBT Blue Label 2',
#  '모던 자바스크립트 Deep Dive',
#  '백만장자 시크릿',
#  '빅터 프랭클의 죽음의 수용소에서',
#  '죽음의 수용소에서',
#  '스파이 패밀리 2',
#  '뿌리깊은 초등국어 독해력 어휘편 1단계(초등 1-2학년 대상)',
#  '푸른 사자 와니니 2: 검은 땅의 주인',
#  'Word Master 수능 2000',
#  '보카바이블 4.0 세트',
#  '뿌리깊은 초등국어 독해력 5단계(초등 5-6학년 대상)',
#  '생각에 관한 생각',
#  'EBS 뉴런 중학 수학1(하)(2022)',
#  '나는 4시간만 일한다',
#  '수력충전 중등 수학1(하)(2021)',
#  '알사탕',
#  '달리기를 말할 때 내가 하고 싶은 이야기',
#  'EBS 50일 고등 수학(하)(2022)',
#  'EBS 50일 고등 수학(상)(2022)',
#  '당신 인생의 이야기',
#  '미움받을 용기 2',
#  '부자 아빠 가난한 아빠 2',
#  '홍길동전: 춤추는 소매 바람을 따라 휘날리니',
#  '동물농장',
#  '플랫폼 비즈니스의 미래',
#  '슈퍼 히어로의 똥 닦는 법',
#  '완자 고등 물리학1(2022)',
#  "샬롯의 거미줄(Charlotte's Web)",
#  'To Kill a Mockingbird',
#  '매일성경(개역개정)(2022년 11/12월호)',
#  '어린왕자 마음의 눈으로 보이는 것들 탁상달력(2023)',
#  '좋아하는 것을 발견하는 법',
#  '혼김치',
#  '한 개의 기쁨이 천 개의 슬픔을 이긴다: 삶과 태도에 관하여',
#  '비전공자도 이해할 수 있는 AI 지식',
#  '클라우스 슈밥의 위대한 리셋',
#  '아레나 옴므+(2022년 11월호)',
#  '개념원리 RPM 중등 수학 2-1(2023)',
#  'EBS 만점왕 초등 수학 4-2(2022)',
#  '엄마 도감',
#  '내 아이를 위한 감정코칭',
#  '주니어 리딩튜터 Level 2',
#  'Holes (1999 Newbery Medal Winner)',
#  '서툰 어른 처방전',
#  '그림의 말들',
#  '과거가 남긴 우울 미래가 보낸 불안',
#  '저만치 혼자서',
#  '너처럼 예쁜 동시ͺ 나태주 동시 따라쓰기',
#  '앵무새 죽이기',
#  '한경무크 실버타운 올가이드',
#  '비즈니스의 미래',
#  '그림 그리기가 이토록 쉬울 줄이야',
#  '비비드 패션 연구실(양장본 Hardcover)',
#  '나를 살게 하는 것들',
#  '박문호 박사의 빅히스토리 공부',
#  '2022 파이팅혼공TV 지게차 운전기능사 필기 한방에 정리',
#  '해커스 토익 실전 1200제 LC Listening 리스닝',
#  '숲속 100층짜리 집',
#  '5년 후 나에게 Q&A a Day(오로라 Edition)',
#  '나는 강물처럼 말해요',
#  '어린이 맞춤법',
#  '주니어 리딩튜터 Level 4',
#  '명상록',
#  '아픔이 길이 되려면',
#  '초등 영문법ͺ 문법이 쓰기다 기본 2',
#  'MIC ON [미니 12집] [MAIN VER]',
#  '2022 위포트 LG그룹 인적성검사 통합 기본서',
#  '2022 하반기 All-New LG그룹 온라인 인적성검사 최신기출유형+모의고사 5회+무료LG특강',
#  '나의 투자는 새벽 4시에 시작된다',
#  '오십의 주역공부',
#  '빠르게 실패하기',
#  '2022 상반기 All-New SKCT SK 종합역량검사 봉투모의고사 5회분+무료SK특강',
#  '버린 쓰레기는 다시 줍지 않는다. 1',
#  '사랑받는 막내는 처음이라. 2',
#  '재벌집 막내아들. 2',
#  '나의 사랑하는 적들에게. 1',
#  '금동. 8',
#  '유일한 순정. 2(완결)',
#  '구궐황도. 8',
#  '후애. 외전',
#  '배타적 연애금지구역 35화',
#  '도쿄 에일리언즈 4(더블특장판)',
#  '2023 시나공 정보처리기사 필기',
#  '30개 도시로 읽는 미국사',
#  '보부아르의 말',
#  '국내 최다 이모티콘 승인 작가 씨엠제이가 알려주는 승인율 99.9% 이모티콘 만들기',
#  '2023 유휘운 행정법총론 진도별 기출문제집(진출)',
#  '착한 아이 버리기',
#  '숲속의 담 5',
#  '해커스 SSAFY (싸피:삼성 청년 SW아카데미) 통합 기본서 SW적성진단+에세이+면접',
#  '다시ͺ 평화',
#  '중학 영문법 클리어 Level 2',
#  '종합물가정보 세트(2022년 10월호)(통권623호)(전2권)',
#  '마더텅 100% 실전대비 MP3 중학영어듣기 24회 모의고사 1학년(2023)',
#  '월간최신 취업에 강한 에듀윌 시사상식(2022년 10월호)',
#  '2023 내 집 마련 가계부',
#  '민쩌미 옛날옛쩜',
#  '신화의 시대',
#  '펀자이씨툰 1: 어디로 가세요 펀자이씨?',
#  '전설의 모험왕 엉덩이 댄디 더 영 4: 드래곤을 찾아서!',
#  '통찰의 시간',
#  '백 번 산 고양이 백꼬선생 1',
#  '바니타스의 수기 10(특장판)',
#  '2023 갓대환 형사법 기출총정리',
#  '전지적 독자 시점 7',
#  '보테로 가족의 사랑 약국',
#  '2023 이동기 영어 유형별 기출문제집',
#  '박병창의 돈을 부르는 매매의 심리',
#  '해빙 잇 올',
#  '세대 감각',
#  'Go Go 카카오프렌즈 25: 네덜란드',
#  '멘탈이 강해지는 연습',
#  '2023 심우철 문법 풀이 전략서',
#  '혼자 공부하는 컴퓨터 구조+운영체제',
#  '우주시대에 오신 것을 환영합니다',
#  '자연스러운 인체 드로잉',
#  '2022 하반기 All-New LG그룹 온라인 인적성검사 최신기출유형+모의고사 5회+무료LG특강',
#  '내 생각과 관점을 수익화하는 퍼스널 브랜딩',
#  '아무도 지켜보지 않지만 모두가 공연을 한다',
#  '차이나 쇼크ͺ 한국의 선택',
#  '혼자 시작하는 사주명리 공부',
#  '오늘은 짠테크 내일은 플렉스',
#  '여기는 커스터드ͺ 특별한 도시락을 팝니다',
#  '꽁꽁꽁 아이스크림',
#  '해커스공무원 영어 비비안 올인원 영문법(9급 공무원)',
#  '입지 센스',
#  'EBS 왕초보영어(하)(2022)',
#  '해커스 토익 실전 1000제 3 LC Listening(리스닝) 토익문제집',
#  '유럽 캠핑 30일',
#  '궤도의 과학 허세(리커버)',
#  '말의 알고리즘',
#  '스토리만이 살길',
#  '흔한남매 과학 탐험대 5: 물리 1',
#  '세상에서 가장 짧은 한국사',
#  '에그박사 7',
#  '2023 시나공 총정리 컴퓨터활용능력 1급 필기',
#  '참 쉬운  평생 반찬 요리책',
#  'EBS 윤혜정의 패턴의 나비효과(2022)',
#  '경매대마왕 반드시 부자 되는 투자의 소신',
#  '당신은 사건 현장에 있습니다',
#  '10일 만에 끝내는 해커스 토익스피킹(토스) 스타트',
#  '경리회계 인사노무 경영지원 실무 설명서',
#  '미적분의 쓸모',
#  '프로세스 이코노미',
#  '노이즈: 생각의 잡음',
#  '브라질에 비가 내리면 스타벅스 주식을 사라',
#  '저 별은 모두 당신을 위해 빛나고 있다',
#  '오감 놀이 동요',
#  '꽃샘바람에 흔들린다면 너는 꽃',
#  '부동산 절세의 기술',
#  '두근두근 편의점',
#  'EBS 수능연계완성 4주 특강 고난도 신유형 국어(2022)(2023 수능 대비)',
#  '운명을 바꾸는 부동산 투자 수업: 기초편',
#  '탐닉',
#  '2022 에듀윌 위험물산업기사 실기 2주끝장',
#  '해커스 토플 리딩(Hackers TOEFL Reading)',
#  '해커스 텝스 기출 보카(TEPS VOCA)',
#  '박봄의 사회·문화 표 분석의 패턴(2022)',
#  '개념+유형 기초탄탄 라이트 중등 수학 1-2(2022)',
#  '개념+유형 실력향상 파워 중등 수학 1-2(2022)',
#  '럭키 드로우',
#  '고양이 해결사 깜냥 4: 눈썰매장을 씽씽 달려라!',
#  'EBS 수능특강 수학영역 수학1(2022)(2023 수능대비)',
#  'EBS 수능특강 수학영역 수학2(2022)(2023 수능대비)',
#  '마더텅 수능기출 모의고사 28회 국어 영역(2022)(2023 수능대비)',
#  'ETS 토익 정기시험 기출입문서 LC 리스닝',
#  '해커스 첫토익 LC+RC+VOCA',
#  '해커스 토익 실전 1000제 RC Reading(리딩) 2 문제집',
#  '딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿',
#  '리얼 오리지널 수능기출 6 9 수능 평가원 모의고사 5개년 15회 고3 국어(2022)(2023 대비)',
#  '디딤돌 초등 수학 기본+응용 6-2(2022)',
#  '위풍당당 여우 꼬리 1: 으스스 미션 캠프',
#  '2022 혼잡(JOB) 농협논술 농협상식',
#  '해커스 토익 실전 1000제 LC Listening(리스닝) 2 문제집',
#  '하루 한 장 365 인문학 달력',
#  '지정학의 힘',
#  '어린이라는 세계',
#  '홀로서기 심리학(7만 부 기념 스페셜 에디션)',
#  'EBS 뉴런 중학 역사1(2022)',
#  '햇빛초 대나무 숲에 새 글이 올라왔습니다',
#  '경제금융용어 700선',
#  '오싹오싹 당근',
#  '스파이 패밀리 3',
#  '중학 국어 3-2 평가문제집 (박영목)(2020)',
#  '최상위 수학 S 초등 6-2(2022)',
#  '뿌리깊은 초등국어 독해력 어휘편 5단계(초등 5-6학년 대상)',
#  '스파이 패밀리 1',
#  '최상위 수학 S 초등 5-2(2022)',
#  '사랑의 기술',
#  '쇼코의 미소',
#  '환경과 생태 쫌 아는 10대',
#  '나의 월급 독립 프로젝트',
#  '페인트',
#  '주니어 리딩튜터 Level 1',
#  '인스파이어드',
#  '종이 동물원',
#  '하마터면 회계를 모르고 일할 뻔했다!',
#  '무기가 되는 스토리',
#  '슬픔을 공부하는 슬픔',
#  '참을 수 없는 존재의 가벼움',
#  '모두 거짓말을 한다',
#  '공부머리 독서법',
#  '도서관을 훔친 아이',
#  '채권투자 핵심 노하우',
#  '엄마의 말하기 연습',
#  '백년 목',
#  '유형으로 격파하는 Listening TAPA(리스닝타파) Level 3',
#  '시끌벅적 정글 사운드북',
#  '안목',
#  '자존감 수업',
#  '내게 사막은 인생의 지도이다',
#  '왜 세계의 절반은 굶주리는가?',
#  '초등 영문법ͺ 문법이 쓰기다 기본 1',
#  '유시민의 글쓰기 특강',
#  '노인과 바다',
#  '1984',
#  '칼 같은 글쓰기',
#  '빨치산의 딸 1',
#  '빨치산의 딸 2',
#  '젊은 베르테르의 슬픔',
#  '끝날 때까지 끝난 게 아니다',
#  '악플 전쟁',
#  '직장인을 위한 실무 구글 스프레드시트',
#  '쓸데없는 생각이 많은 편',
#  '숨은그림찾기: 북적북적 직업탐험',
#  '세계 나라 사전',
#  '어느 날 거위가',
#  '나쁜 회사 재무제표',
#  '진화 인간',
#  '그러니 그대 사라지지 말아라',
#  '2023 식객 허영만의 세상에서 가장 맛있는 캘린더',
#  '워드마스터 중등 고난도',
#  '기억을 지워 주는 문방구',
#  '세포충전건강법',
#  '1일 1로그 100일 완성 IT 지식',
#  '열두 달 세시 풍속 이야기',
#  '샬롯의 거미줄',
#  '모스크바의 신사',
#  '야밤의 공대생 만화',
#  '그 가이드가 집착광공의 품에서 벗어나는 방법. 4',
#  '고등 국어 문법(2023)',
#  '필요한 것만 골라 배우는 모던 C++',
#  '왜그래ͺ가 아니라 괜찮아',
#  '흔한남매 이상한 나라의 고전 읽기 1: 춘향전 토끼전 옹고집전',
#  '붉은 무늬 상자',
#  '사마아',
#  '마더텅 전국연합 학력평가 기출문제집 고1 국어 독서(2022)',
#  '딥러닝 컴퓨터 비전',
#  '파타고니아ͺ 파도가 칠 때는 서핑을',
#  "리더스뱅크 Reader's Bank Level 7",
#  '반짝반짝 별찌',
#  '바쁜 초등학생을 위한 빠른 구구단',
#  '세상 쉬운 영문법',
#  '건축설비기사실기(23년대비)',
#  '틴틴팅클! 특별부록 박스 세트',
#  '다시 만난 세계: 쩌미문 1',
#  '개념 플러스 유형 기본 라이트 초등 수학 5-1(2023)',
#  '플라스틱 인간']

# %%
author_list
# Out:
# ['김난도 외',
#  '김달',
#  '박재연',
#  '레슬리 마샹 외',
#  '김훈',
#  '지나영',
#  '정지아',
#  '김호연',
#  '에듀윌 취업연구소',
#  '자청',
#  '최서영',
#  '허스트중앙 편집부',
#  '허스트중앙 편집부',
#  '우즈훙 외',
#  '김호연',
#  '김성공',
#  '해커스 취업교육연구소',
#  '올리버 그랜트 외',
#  '장재형',
#  '허스트중앙 편집부',
#  '김주혜 외',
#  '아니 에르노 외',
#  '충페이충 외',
#  '이민진 외',
#  '이민진 외',
#  '게리 켈러 외',
#  '고명환',
#  '앤절라 더크워스 외',
#  '로버트 기요사키 외',
#  '피아 칼리슨 외',
#  '교보문고',
#  '한국데이터진흥원',
#  '김난도 외',
#  '김연수',
#  '강환국',
#  '발타자르 그라시안 외',
#  '교보문고',
#  '교보문고',
#  '해커스 취업교육연구소',
#  '데일 카네기 외',
#  '김승호',
#  '세스 스티븐스 다비도위츠 외',
#  '에쿠니 가오리 외',
#  '닉 매기울리 외',
#  '안성은(Brand Boy)',
#  '소강석',
#  '박윤식 외',
#  '김동완',
#  '무라세 다케시 외',
#  '해커스 취업교육연구소',
#  '최태성',
#  '류쉬안 외',
#  'David Cho',
#  'ETS',
#  '이철',
#  '박찬욱 (감독) 외',
#  '엠제이 드마코 외',
#  'ETS',
#  '박찬위',
#  '허지웅',
#  '김다슬',
#  '최태성',
#  'EBS교육방송 편집부',
#  '천위안 외',
#  '도리 힐레스타드 버틀러 외',
#  '최태성',
#  'EBS교육방송 편집부',
#  '팀 페리스 외',
#  '리처드 도킨스 외',
#  '편집부',
#  '존 크럼볼츠 외',
#  '서영조',
#  '제임스 클리어 외',
#  '이서희',
#  '유목민',
#  '그랜트 카돈 외',
#  '진병관',
#  'SD적성검사연구소',
#  '유영만 외',
#  '개리 마커스 외',
#  'EBS교육방송 편집부',
#  '진은영',
#  '김민형',
#  'EBS교육방송 편집부',
#  '황보름',
#  '두레문학 편집부',
#  '이병률',
#  '김범준',
#  '이슬아',
#  '생명 편집부',
#  '안치현 외',
#  '김시덕',
#  '해커스 취업교육연구소',
#  '히가시노 게이고 외',
#  '오은영 외',
#  '에듀윌 취업연구소',
#  '김영하',
#  '에런 레이놀즈 외',
#  '오빠두(전진권)',
#  '마이클 모부신 외',
#  '교보문고',
#  '우석',
#  '최병천',
#  '윤인성',
#  '손원평',
#  'EBS교육방송 편집부',
#  '홍범준 외',
#  '아니 에르노 외',
#  '윤지영',
#  '안도현',
#  '레이 달리오 외',
#  '윤종식',
#  '박재연 외',
#  '짐 퀵 외',
#  '박웅현',
#  '설민석 외',
#  '론 프리드먼 외',
#  '최겸',
#  '에듀윌 취업연구소',
#  '데일 카네기 외',
#  '이즈미 마사토 외',
#  'EBS교육방송 편집부',
#  'B. A. 패리스 외',
#  '박준철',
#  '김지현',
#  '룰루 밀러 외',
#  '앙드레 코스톨라니 외',
#  'NE능률 영어교육연구소',
#  '유은실',
#  '루리 외',
#  'EBS교육방송 편집부',
#  '정선근',
#  '최정수 외',
#  '나땅(이소라)',
#  'tvN STORY 〈벌거벗은 한국사〉 제작팀 외',
#  '오은영',
#  '황웅근',
#  '비상교육 편집부',
#  '브라이언 헤어 외',
#  '김훈',
#  '폴 심프슨 외',
#  '이사 레슈코 외',
#  '박지현',
#  '김민철',
#  '마이클 브룩스 외',
#  'EBS교육방송 편집부',
#  'EBS교육방송 편집부',
#  '너나위',
#  'EBS교육방송 편집부',
#  '민영기 외',
#  '최종엽',
#  '하정훈',
#  '레이첼 카슨 외',
#  '롭 무어 외',
#  '노지영 외',
#  '아니 에르노 외',
#  '지민석',
#  'EBS교육방송 편집부',
#  '박영숙 외',
#  '도나 바르바 이게라 외',
#  '지용근 외',
#  '다니엘 핑크 외',
#  '세이카 료겐 외',
#  '이치조 미사키 외',
#  '팀 마샬 외',
#  '안인숙',
#  '유발 하라리 외',
#  '서은',
#  '한스 게오르크 호이젤 외',
#  '편혜영 외',
#  '윤종혁 외',
#  '에듀원 편집부',
#  '칩 히스 외',
#  'STRAY KIDS(스트레이 키즈)',
#  '나태주',
#  'SD적성검사연구소',
#  '정지성 외',
#  '이시형',
#  'EBS교육방송 편집부',
#  '백난도 외',
#  '오건영',
#  '간호사시험연구소',
#  '최태성',
#  '홍범준 외',
#  '안인숙',
#  '김지수 외',
#  '가바사와 시온 외',
#  '데이비드 버스 외',
#  '마더텅 편집부',
#  '박성우 외',
#  'R. J. Palacio',
#  '우노 다카시 외',
#  '칼 필레머 외',
#  '이상우 외',
#  '이어령',
#  '김기훈 외',
#  '정선근',
#  '정지아',
#  '안진환 외',
#  '신윤미',
#  '최태성 외',
#  '고시넷 NCS 연구소',
#  '최태성 외',
#  'EBS교육방송 편집부',
#  '박세니',
#  '해커스 오픽연구소',
#  '에릭 와이너 외',
#  '이미예',
#  '대니얼 J. 레비틴 외',
#  '다자이 오사무 외',
#  '교보문고',
#  '박위',
#  '김성욱',
#  '기시미 이치로 외',
#  '칼 세이건 외',
#  '이근상',
#  '아니 에르노 외',
#  '이수민 외',
#  '매거진 B 편집부',
#  '일레인 N. 아론 외',
#  '이창용',
#  '부동산읽어주는남자(정태익)',
#  '김성근',
#  '해커스 취업교육연구소',
#  '김은진',
#  '에듀윌 취업연구소',
#  '정서경 외',
#  '백영 외',
#  '폴커 키츠 외',
#  '비상교육 편집부',
#  '이꽃님',
#  '김갑진',
#  '모건 하우절 외',
#  '한윤섭 외',
#  '재레드 다이아몬드 외',
#  '리처드 탈러 외',
#  '정선근',
#  '마더텅 편집부',
#  '헤르만 헤세 외',
#  'SD적성검사연구소',
#  '아니 에르노 외',
#  '이수정',
#  '마루야마 쿠가네 외',
#  '김초엽',
#  '크리스티앙 클로 외',
#  '프리드리히 니체 외',
#  '장강명',
#  '이치조 미사키 외',
#  '임은정',
#  '손원평',
#  '셀리',
#  '신민숙',
#  '간다 마사노리 외',
#  'EBS교육방송 편집부',
#  'David Cho',
#  'David Cho',
#  '김초엽',
#  '비상교육 편집부',
#  '디딤돌 편집부',
#  '마리 홀 에츠 외',
#  '페터 비에리 외',
#  '론다 번 외',
#  'LE SSERAFIM(르세라핌)',
#  '이재문 외',
#  '황영미',
#  '이홍섭',
#  '손원평 외',
#  '김기태 외',
#  '김경민',
#  '장강명',
#  '디딤돌 편집부',
#  'Lawrence J. Zwier',
#  '네비게이토 편집부',
#  '지나영',
#  '장재형',
#  '구세희 외',
#  '발타자르 그라시안 외',
#  '미래나비',
#  '구중탑',
#  '구중탑',
#  '구중탑',
#  ' 앤드비  ',
#  '정호승',
#  '김상준',
#  '이해원',
#  '황성민 외',
#  'EBS교육방송 편집부',
#  '황정현 외',
#  '채사장 외',
#  '심윤경',
#  '이현 외',
#  'tvn<벌거벗은세계사>제작팀',
#  '류대곤 외',
#  '우스이 류이치로 외',
#  '황인기 외',
#  'EBS교육방송 편집부',
#  '비욘 나티코 린데블라드 외',
#  '해커스 취업교육연구소',
#  '최태성',
#  '곽해선',
#  'BLW 연구소 외',
#  '발타자르 그라시안 외',
#  '서영조',
#  '이현 외',
#  '김영익',
#  '김지안 외',
#  '김선현',
#  '이나모리 가즈오 외',
#  '김기훈 외',
#  '유대영 외',
#  '문재인 외',
#  '아니 에르노 외',
#  '문경민',
#  '홍범준 외',
#  '로버트 C. 마틴 외',
#  '제롬 데이비드 샐린저 외',
#  '김호연',
#  '구중탑',
#  '구중탑',
#  'MIZUHO KUSANAGI',
#  'BLW 연구소 외',
#  '발타자르 그라시안 외',
#  '서영조',
#  '이현 외',
#  '김영익',
#  '김지안 외',
#  '김선현',
#  '이나모리 가즈오 외',
#  '김기훈 외',
#  '유대영 외',
#  '문재인 외',
#  '아니 에르노 외',
#  '문경민',
#  '홍범준 외',
#  '로버트 C. 마틴 외',
#  '제롬 데이비드 샐린저 외',
#  '김호연',
#  '구중탑',
#  '구중탑',
#  'MIZUHO KUSANAGI',
#  '홍범준 외',
#  'tvn<벌거벗은세계사>제작팀',
#  '은현장',
#  '백난도 외',
#  '디딤돌 편집부',
#  '홍범준 외',
#  '해커스 오픽연구소',
#  '피터 린치 외',
#  '매트 헤이그 외',
#  'ETS',
#  '헤티 판 더 레이트 외',
#  '윤혜정',
#  '유시민',
#  '아니 에르노 외',
#  '박희철(파이팅팔콘) 외',
#  '정주희',
#  '에런 레이놀즈 외',
#  'ETS',
#  '홍자성 외',
#  '송희창',
#  '애덤 그랜트 외',
#  '로이스 로리 외',
#  'C. S. 루이스 외',
#  '김용세 외',
#  'Tae Keller',
#  '채사장 외',
#  '이선미 외',
#  '채사장',
#  '박혜윤',
#  '포터 스타일 외',
#  '피터 버고지언 외',
#  '홍범준 외',
#  '박동창',
#  '예림당 편집부',
#  '백유연 외',
#  '유시민',
#  'Eiichiro Oda',
#  '마더텅 편집부',
#  '해커스어학연구소',
#  '최은영',
#  '나폴레온 힐 외',
#  '이민진 외',
#  '김미정 외',
#  '구중탑',
#  'JJYARONG',
#  '리버 진',
#  '김지혜',
#  '한정희 외',
#  '김용섭',
#  '전경섭',
#  '김현석',
#  '이해찬',
#  '설민석 외',
#  'One 외',
#  '헤이든 핀치 외',
#  '권글(권혁탁)',
#  '이현 외',
#  'SD적성검사연구소',
#  '김나영 외',
#  '제임스 굿윈 외',
#  'ETS',
#  '에듀윌 취업연구소',
#  '최재천 외',
#  'EBS교육방송 편집부',
#  'EBS교육방송 편집부',
#  '김나영 외',
#  '이정기 외',
#  '애나 렘키 외',
#  '보도 섀퍼 외',
#  '아니 에르노 외',
#  '홍범준 외',
#  'tvn<벌거벗은세계사>제작팀',
#  '매튜 룬 외',
#  '해커스 일본어연구소',
#  'EBS교육방송 편집부',
#  '혼Job취업연구소',
#  '마더텅 편집부',
#  'NE능률 영어교육연구소',
#  '해커스 어학연구소',
#  'EBS교육방송 편집부',
#  '안인숙',
#  '마더텅 편집부',
#  '마더텅 편집부',
#  '퍼포먼스 코치 리아',
#  '이미예',
#  '홍범준 외',
#  '이나모리 가즈오 외',
#  '존 그레이 외',
#  '고경희',
#  '마이클 샌델 외',
#  '편집부 외',
#  '디딤돌 편집부',
#  '델리아 오언스 외',
#  '양귀자',
#  '하정훈 외',
#  '로버트 기요사키 외',
#  '이이 외',
#  'E. B. White 외',
#  '이홍섭',
#  '유종오',
#  '한강',
#  '김리리 외',
#  '장문철',
#  '채사장 외',
#  '손현주',
#  '채사장 외',
#  '마플 편집부',
#  '리버 진',
#  '야생꽃',
#  'EBS교육방송 편집부',
#  '오상진',
#  '위기철',
#  '윤영철',
#  '구도 치아키 외',
#  '교보문고',
#  '황현진',
#  '프란체스카 피로네 외',
#  '한날 외',
#  '나태주',
#  '이홍섭',
#  '홍범준 외',
#  '진민규 외',
#  '이민진 외',
#  '자청',
#  '야생꽃',
#  '구중탑',
#  '구중탑',
#  '화광신문사 출판국 법련부編',
#  '박유화',
#  '브렛 스콧 외',
#  '아니 에르노 외',
#  '도리 힐레스타드 버틀러 외',
#  '권석준',
#  '임윤정 외',
#  '허심양',
#  '양봄내음 외',
#  '김영익 외',
#  '박혜란 외',
#  '고희정 외',
#  '칩 히스 외',
#  '조정민',
#  '한국교원대학교 역사교육과 교수진',
#  '배미정 외',
#  '안선우',
#  '유창호',
#  '김정환',
#  'SD적성검사연구소',
#  '해커스 취업교육연구소',
#  '삼성출판사 편집부',
#  '김종수',
#  '이중석',
#  'Sam Norris 외',
#  'EBS교육방송 편집부',
#  'EBS교육방송 편집부',
#  '백난도 외',
#  '천재교육 편집부',
#  '김상현',
#  '수잔 샤키야 외',
#  '아니 에르노 외',
#  '고시넷 NCS 연구소',
#  '엘렌 랭어 외',
#  '김혜정',
#  'EBS교육방송 편집부',
#  'David Cho',
#  '강성태',
#  '마더텅 편집부',
#  '마더텅 편집부',
#  '홍범준 외',
#  '수경출판사 편집부',
#  '홍범준 외',
#  '손웅정',
#  '해커스 어학연구소',
#  '정영욱',
#  '브라이언 그린 외',
#  '지나영',
#  '정세랑',
#  '안데르스 한센 외',
#  '조예은',
#  '채사장',
#  '알베르 카뮈 외',
#  'Lee, Min Jin',
#  '마쓰이에 마사시 외',
#  '마이클 샌델 외',
#  '양귀자',
#  '히가시노 게이고 외',
#  'L. 프랭크 바움 외',
#  '이오덕',
#  '동아출판 편집부',
#  '김민형',
#  '고정욱 외',
#  '교보문고',
#  '정서아',
#  '신미선',
#  '타일러 라쉬',
#  'C. S. 루이스 외',
#  '루이스 새커 외',
#  '오은영',
#  '송길영',
#  '에듀원 편집부',
#  '콜린 브라이어 외',
#  '요시타케 신스케 외',
#  '채사장',
#  '임정선',
#  '경선식',
#  '마더텅 편집부',
#  '김준근',
#  '박현숙 외',
#  '마더텅 편집부',
#  '남정석',
#  '박상영',
#  '개념원리 편집부',
#  '김선호',
#  '밥 프록터 외',
#  'EBS교육방송 편집부',
#  '해커스어학연구소',
#  '이재국 외',
#  '김기훈 외',
#  '박응용',
#  '김상욱',
#  '정혜신',
#  'Chris Grabenstein',
#  'Draper, Sharon M.',
#  '프리드리히 니체 외',
#  '그랜트 카돈 외',
#  '교보문고',
#  '아로하',
#  '구중탑',
#  '비애가',
#  'KAIST 문술미래전략대학원 미래전략연구센터',
#  '에듀윌 취업연구소',
#  '나도코딩',
#  '유창호',
#  '마쓰무라 게이코 외',
#  '최설희 외',
#  '박성우 외',
#  '김강현 외',
#  '송도수 외',
#  '홍춘욱',
#  '개념원리 편집부',
#  '커넥팅랩',
#  '한병철 외',
#  '박현숙',
#  '전극진 외',
#  '이수현 외',
#  '신용한 외',
#  '천현우',
#  '조예은',
#  '데니스 뇌르마르크 외',
#  '노현태',
#  '후지이 아사리',
#  '공하성',
#  '고광윤',
#  '이해원',
#  '에듀윌 취업연구소',
#  '에듀윌 취업연구소',
#  '이민경 외',
#  '이홍섭',
#  '해커스 어학연구소',
#  '박신영',
#  '에이미 스미스 외',
#  '이해원',
#  '해커스 취업교육연구소',
#  '조한경 외',
#  '해커스 어학연구소',
#  '임선정 외',
#  '이영방 외',
#  'EBS교육방송 편집부',
#  '김선영',
#  '박노해',
#  '에듀윌 취업연구소',
#  '문두식',
#  '권철민',
#  'EBS교육방송 편집부',
#  '팀 마샬 외',
#  '이홍섭',
#  '이홍섭',
#  '김헌',
#  '위포트 연구소',
#  'David Cho',
#  '도로교통공단',
#  'EBS교육방송 편집부',
#  'EBS교육방송 편집부',
#  '마더텅 편집부',
#  '에듀윌 한국사교육연구소',
#  '수경출판사 편집부',
#  '조원재',
#  '마더텅 편집부',
#  '마더텅 편집부',
#  '홍범준 외',
#  '켈리 최',
#  '피터 틸 외',
#  '한강',
#  '해커스 어학연구소',
#  '에듀원 편집부',
#  '에듀원 편집부',
#  '에듀원 편집부',
#  '리사 팰트먼 배럿 외',
#  '홍범준 외',
#  '이꽃님',
#  '박성현',
#  '짐 콜린스 외',
#  '간다 마사노리 외',
#  '능률영어교육연구소',
#  '이웅모',
#  '하브 에커 외',
#  '빅터 프랭클 외',
#  '빅터 프랭클 외',
#  'Tatsuya Endo 외',
#  '마더텅 편집부',
#  '이현 외',
#  '김태희',
#  '허민',
#  '마더텅 편집부',
#  '대니얼 카너먼 외',
#  'EBS교육방송 편집부',
#  '팀 페리스 외',
#  '수경출판사 편집부',
#  '백희나',
#  '무라카미 하루키 외',
#  'EBS 편집부',
#  'EBS 편집부',
#  '테드 창 외',
#  '기시미 이치로 외',
#  '로버트 기요사키 외',
#  '류수열 외',
#  '조지 오웰 외',
#  '이성열 외',
#  '안영은 외',
#  '류상호 외',
#  '롱테일북스 편집부',
#  'Lee, Harper',
#  '성서유니온선교회 편집부',
#  '북엔 편집부',
#  '이다혜',
#  '배양자',
#  '조우성',
#  '박상길 외',
#  '클라우스 슈밥 외',
#  '아레나옴므 편집부',
#  '개념원리 편집부',
#  'EBS교육방송 편집부',
#  '권정민 외',
#  '최성애 외',
#  'NE능률영어교육연구소',
#  'Louis Sachar',
#  '박대선',
#  '태지원',
#  '김아라',
#  '김훈',
#  '나태주 외',
#  '하퍼 리 외',
#  '문성택 외',
#  '야마구치 슈 외',
#  '이기주',
#  '도미(송닷옴) 외',
#  '김창옥',
#  '박문호',
#  '프로듀서 혼공쌤',
#  '해커스어학연구소',
#  '이와이 도시오 외',
#  '포터 스타일 외',
#  '조던 스콧 외',
#  '한날 외',
#  'NE능률영어교육연구소',
#  '마르쿠스 아우렐리우스 외',
#  '김승섭',
#  '키 영어학습방법연구소',
#  'MAMAMOO(마마무)',
#  '위포트 연구소',
#  'SD적성검사연구소',
#  '유목민',
#  '김동완',
#  '존 크럼볼츠 외',
#  'SD적성검사연구소',
#  '배고픈밤',
#  '미래나비',
#  '산경(山景)',
#  '틸다킴',
#  '한청낙화',
#  '문수진',
#  '구중탑',
#  '내설',
#  ' 서울미디어코믹스(서울문화사)  ',
#  'NAOE 외',
#  '김정준 외',
#  '김봉중',
#  '시몬 드 보부아르 외',
#  '씨엠제이(최민정)',
#  '유휘운',
#  '송주현',
#  '다홍',
#  '해커스 취업교육연구소',
#  '임동원',
#  '동아영어콘텐츠연구팀',
#  '한국물가정보 편집부',
#  '마더텅 편집부',
#  '에듀윌 상식연구소',
#  '김유라',
#  '민쩌미  외',
#  '토머스 불핀치 외',
#  '엄유진 외',
#  '하루하라 로빈슨 외',
#  '신수정',
#  '정연철 외',
#  'Jun Mochizuki 외',
#  '갓대환 형사법 연구실',
#  '싱숑 외',
#  '이선영',
#  '이동기 영어교육연구소',
#  '박병창',
#  '존 아사라프 외',
#  '바비 더피 외',
#  '김미영 외',
#  '데이먼 자하리아데스 외',
#  '심우철',
#  '강민철',
#  '켈리 제라디 외',
#  '박경선',
#  'SD적성검사연구소',
#  '촉촉한마케터(조한솔)',
#  '비비언 고닉 외',
#  '한청훤',
#  '김원',
#  '김경필',
#  '가토 겐 외',
#  '윤정주',
#  '비비안',
#  '훨훨(박성혜)',
#  '마스터유진',
#  '해커스 어학연구소',
#  '안수지',
#  '궤도',
#  '고은미 외',
#  '리사 크론 외',
#  '이현진 외',
#  '김재원',
#  '박송이 외',
#  '길벗RD',
#  '노고은 외',
#  'EBS교육방송 편집부',
#  '심태승',
#  '모데스토 가르시아 외',
#  'David Cho',
#  '손원준',
#  '한화택',
#  '오바라 가즈히로 외',
#  '대니얼 카너먼 외',
#  '피터 나바로 외',
#  '손힘찬(오가타 마리토)',
#  '권오순 외 외',
#  '류시화',
#  '김동우(투에이스) 외',
#  '김영진',
#  'EBS교육방송 편집부',
#  '정태익',
#  '아니 에르노 외',
#  '최창률',
#  'David Cho',
#  'David Cho',
#  '박봄',
#  '비상교육 편집부',
#  '비상교육 편집부',
#  '드로우앤드류',
#  '홍민정 외',
#  'EBS교육방송 편집부',
#  'EBS교육방송 편집부',
#  '마더텅 편집부',
#  'ETS',
#  '해커스 어학연구소',
#  '해커스어학연구소',
#  '김세희(세빛희)',
#  '입시플라이 편집부',
#  '디딤돌 편집부',
#  '손원평 외',
#  '석의현 외',
#  '해커스어학연구소',
#  '김종원 외',
#  '김동기',
#  '김소영',
#  '라라 E. 필딩 외',
#  'EBS교육방송 편집부',
#  '황지영 외',
#  '한국은행',
#  '애런 레이놀즈 외',
#  'Tatsuya Endo 외',
#  '박영목 외 14인',
#  '디딤돌 편집부',
#  '마더텅 편집부',
#  'Tatsuya Endo',
#  '디딤돌 편집부',
#  '에리히 프롬 외',
#  '최은영',
#  '최원형 외',
#  '유목민',
#  '이희영',
#  'NE능률영어교육연구소',
#  '마티 케이건 외',
#  '켄 리우 외',
#  '김수헌 외',
#  '도널드 밀러 외',
#  '신형철',
#  '밀란 쿤데라 외',
#  '세스 스티븐스 다비도위츠 외',
#  '최승필',
#  '알프레도 고메스 세르다 외',
#  '마경환',
#  '박재연',
#  '정선근',
#  '비상교육 편집부',
#  '샘 태플린 외',
#  '유홍준',
#  '윤홍균',
#  '남영호 외',
#  '장 지글러 외',
#  '키 영어학습방법연구소',
#  '유시민',
#  '어니스트 헤밍웨이 외',
#  '조지 오웰 외',
#  '아니 에르노 외',
#  '정지아',
#  '정지아',
#  '요한 볼프강 폰 괴테 외',
#  '아재글(박순경)',
#  '이규희 외',
#  '진은영',
#  '이민수',
#  '애플비북스 편집부 외',
#  '테즈카 아케미 외',
#  '전예진',
#  '이대훈',
#  '방미진 외',
#  '박노해',
#  '미래출판기획 외',
#  '박혜란 외',
#  '조규미 외',
#  '심영기',
#  '브라이언 W. 커니핸 외',
#  '박혜숙 외',
#  '엘윈 브룩스 화이트 외',
#  '에이모 토울스 외',
#  '맹기완',
#  '야생꽃',
#  '동아출판 편집부',
#  '페터 고칠링 외',
#  '박상영',
#  '최재훈 외',
#  '김선영',
#  '마리 파블렌코 외',
#  '마더텅 편집부',
#  '송정현',
#  '이본 쉬나드 외',
#  '이장돌',
#  '윤미경 외',
#  '강난영 외',
#  '윤여홍',
#  '조성안',
#  '난 외',
#  '샌드박스스토리 키즈 편집부',
#  '비상교육 편집부',
#  '안수민 외']

# %%
price_list
# Out:
# ['17,100원',
#  '14,850원',
#  '13,320원',
#  '15,120원',
#  '14,400원',
#  '16,920원',
#  '13,500원',
#  '12,600원',
#  '20,700원',
#  '15,750원',
#  '14,400원',
#  '12,260원',
#  '12,260원',
#  '14,220원',
#  '12,600원',
#  '15,300원',
#  '16,110원',
#  '20,700원',
#  '14,400원',
#  '12,260원',
#  '16,200원',
#  '9,000원',
#  '16,020원',
#  '14,220원',
#  '14,220원',
#  '12,600원',
#  '15,120원',
#  '14,400원',
#  '14,220원',
#  '13,500원',
#  '45,000원',
#  '17,820원',
#  '13,300원',
#  '12,600원',
#  '22,500원',
#  '12,420원',
#  '19,000원',
#  '24,000원',
#  '17,010원',
#  '10,350원',
#  '16,020원',
#  '16,920원',
#  '13,320원',
#  '17,820원',
#  '16,920원',
#  '8,100원',
#  '18,000원',
#  '16,200원',
#  '12,600원',
#  '13,410원',
#  '17,550원',
#  '15,300원',
#  '11,610원',
#  '16,020원',
#  '14,400원',
#  '29,700원',
#  '15,750원',
#  '16,020원',
#  '12,420원',
#  '14,220원',
#  '15,840원',
#  '13,500원',
#  '7,650원',
#  '16,020원',
#  '11,700원',
#  '13,050원',
#  '7,200원',
#  '16,200원',
#  '18,000원',
#  '140원',
#  '14,850원',
#  '14,400원',
#  '14,400원',
#  '14,850원',
#  '17,820원',
#  '15,120원',
#  '16,920원',
#  '15,400원',
#  '15,300원',
#  '12,420원',
#  '8,550원',
#  '10,800원',
#  '14,400원',
#  '9,900원',
#  '13,500원',
#  '9,500원',
#  '14,220원',
#  '14,220원',
#  '13,500원',
#  '4,750원',
#  '12,600원',
#  '16,200원',
#  '20,610원',
#  '16,020원',
#  '15,750원',
#  '16,200원',
#  '12,600원',
#  '11,700원',
#  '18,900원',
#  '16,200원',
#  '58,500원',
#  '15,300원',
#  '19,800원',
#  '19,800원',
#  '10,800원',
#  '9,900원',
#  '14,400원',
#  '10,800원',
#  '15,750원',
#  '10,800원',
#  '34,200원',
#  '25,200원',
#  '16,200원',
#  '15,120원',
#  '16,200원',
#  '11,700원',
#  '16,020원',
#  '19,800원',
#  '20,700원',
#  '10,350원',
#  '13,500원',
#  '13,050원',
#  '14,400원',
#  '37,800원',
#  '10,800원',
#  '15,300원',
#  '10,800원',
#  '13,500원',
#  '11,700원',
#  '10,350원',
#  '7,200원',
#  '16,650원',
#  '7,000원',
#  '18,000원',
#  '16,920원',
#  '14,400원',
#  '13,500원',
#  '15,750원',
#  '19,800원',
#  '11,200원',
#  '19,800원',
#  '25,200원',
#  '15,120원',
#  '15,120원',
#  '19,800원',
#  '5,400원',
#  '5,400원',
#  '17,820원',
#  '9,630원',
#  '24,210원',
#  '14,400원',
#  '17,010원',
#  '16,200원',
#  '14,400원',
#  '12,600원',
#  '13,950원',
#  '12,600원',
#  '8,100원',
#  '16,200원',
#  '16,200원',
#  '18,000원',
#  '16,200원',
#  '13,500원',
#  '12,600원',
#  '15,300원',
#  '14,400원',
#  '19,800원',
#  '13,950원',
#  '16,200원',
#  '9,000원',
#  '20,610원',
#  '12,600원',
#  '13,500원',
#  '16,300원',
#  '9,000원',
#  '12,600원',
#  '14,400원',
#  '14,400원',
#  '8,820원',
#  '13,050원',
#  '16,920원',
#  '18,900원',
#  '13,950원',
#  '13,950원',
#  '15,300원',
#  '14,850원',
#  '13,500원',
#  '19,800원',
#  '12,510원',
#  '9,900원',
#  '6,400원',
#  '12,600원',
#  '15,300원',
#  '19,800원',
#  '14,220원',
#  '17,100원',
#  '16,650원',
#  '12,000원',
#  '11,000원',
#  '16,200원',
#  '13,500원',
#  '19,800원',
#  '13,500원',
#  '5,400원',
#  '14,220원',
#  '14,310원',
#  '16,200원',
#  '12,420원',
#  '19,800원',
#  '8,100원',
#  '36,000원',
#  '13,500원',
#  '16,200원',
#  '13,410원',
#  '17,910원',
#  '14,220원',
#  '9,720원',
#  '16,200원',
#  '19,000원',
#  '16,200원',
#  '17,550원',
#  '27,000원',
#  '16,020원',
#  '13,410원',
#  '18,000원',
#  '15,750원',
#  '13,500원',
#  '30,510원',
#  '14,400원',
#  '16,650원',
#  '10,350원',
#  '16,200원',
#  '17,820원',
#  '10,800원',
#  '25,200원',
#  '19,800원',
#  '17,550원',
#  '13,410원',
#  '7,200원',
#  '19,800원',
#  '13,050원',
#  '25,200원',
#  '10,800원',
#  '14,400원',
#  '15,300원',
#  '14,220원',
#  '14,400원',
#  '12,600원',
#  '16,200원',
#  '13,500원',
#  '16,200원',
#  '13,950원',
#  '15,300원',
#  '9,900원',
#  '16,920원',
#  '15,210원',
#  '13,500원',
#  '11,700원',
#  '13,500원',
#  '8,550원',
#  '14,400원',
#  '12,420원',
#  '10,100원',
#  '10,800원',
#  '10,350원',
#  '16,200원',
#  '11,700원',
#  '3,150원',
#  '15,300원',
#  '14,400원',
#  '14,400원',
#  '12,600원',
#  '3,600원',
#  '15,040원',
#  '13,000원',
#  '10,000원',
#  '7,590원',
#  '3,500원',
#  '2,900원',
#  '2,900원',
#  '2,900원',
#  '600원',
#  '9,900원',
#  '16,200원',
#  '17,100원',
#  '16,200원',
#  '8,820원',
#  '56,700원',
#  '13,500원',
#  '11,700원',
#  '10,800원',
#  '20,700원',
#  '14,400원',
#  '16,200원',
#  '16,110원',
#  '9,630원',
#  '14,400원',
#  '23,310원',
#  '16,200원',
#  '19,800원',
#  '21,150원',
#  '13,500원',
#  '13,500원',
#  '9,720원',
#  '16,650원',
#  '9,000원',
#  '17,820원',
#  '14,400원',
#  '14,400원',
#  '12,600원',
#  '15,750원',
#  '10,800원',
#  '11,250원',
#  '14,400원',
#  '29,700원',
#  '7,200원',
#  '9,800원',
#  '2,900원',
#  '2,900원',
#  '2,500원',
#  '21,150원',
#  '13,500원',
#  '13,500원',
#  '9,720원',
#  '16,650원',
#  '9,000원',
#  '17,820원',
#  '14,400원',
#  '14,400원',
#  '12,600원',
#  '15,750원',
#  '10,800원',
#  '11,250원',
#  '14,400원',
#  '29,700원',
#  '7,200원',
#  '9,800원',
#  '2,900원',
#  '2,900원',
#  '2,500원',
#  '14,850원',
#  '20,700원',
#  '15,120원',
#  '12,150원',
#  '13,500원',
#  '13,950원',
#  '14,310원',
#  '23,400원',
#  '14,220원',
#  '16,200원',
#  '19,800원',
#  '13,500원',
#  '14,850원',
#  '11,250원',
#  '16,200원',
#  '19,800원',
#  '11,700원',
#  '11,610원',
#  '4,500원',
#  '14,400원',
#  '15,750원',
#  '10,800원',
#  '12,600원',
#  '11,700원',
#  '6,700원',
#  '13,500원',
#  '14,400원',
#  '17,820원',
#  '15,120원',
#  '15,120원',
#  '15,120원',
#  '14,400원',
#  '15,300원',
#  '8,000원',
#  '10,800원',
#  '15,750원',
#  '4,950원',
#  '17,910원',
#  '16,110원',
#  '13,050원',
#  '16,200원',
#  '12,500원',
#  '11,200원',
#  '2,900원',
#  '1,000원',
#  '1,000원',
#  '15,750원',
#  '27,000원',
#  '16,200원',
#  '12,150원',
#  '18,000원',
#  '20,700원',
#  '11,700원',
#  '4,950원',
#  '15,300원',
#  '13,680원',
#  '10,800원',
#  '19,800원',
#  '15,120원',
#  '17,910원',
#  '17,550원',
#  '15,300원',
#  '14,850원',
#  '5,850원',
#  '5,850원',
#  '14,850원',
#  '16,920원',
#  '16,200원',
#  '15,300원',
#  '12,150원',
#  '14,850원',
#  '20,700원',
#  '13,500원',
#  '12,510원',
#  '8,190원',
#  '20,700원',
#  '16,110원',
#  '13,950원',
#  '17,820원',
#  '14,400원',
#  '15,300원',
#  '13,410원',
#  '13,410원',
#  '13,500원',
#  '12,420원',
#  '14,400원',
#  '14,400원',
#  '15,120원',
#  '27,000원',
#  '16,200원',
#  '10,800원',
#  '13,500원',
#  '14,400원',
#  '13,500원',
#  '26,820원',
#  '14,850원',
#  '16,200원',
#  '5,650원',
#  '14,400원',
#  '16,200원',
#  '13,500원',
#  '9,900원',
#  '16,920원',
#  '12,600원',
#  '10,800원',
#  '12,600원',
#  '18,000원',
#  '3,400원',
#  '3,300원',
#  '10,800원',
#  '14,400원',
#  '10,800원',
#  '13,050원',
#  '12,600원',
#  '4,000원',
#  '15,120원',
#  '12,600원',
#  '11,700원',
#  '12,600원',
#  '15,300원',
#  '14,850원',
#  '25,920원',
#  '12,500원',
#  '12,300원',
#  '3,000원',
#  '2,900원',
#  '2,900원',
#  '1,500원',
#  '1,000원',
#  '17,100원',
#  '12,600원',
#  '11,700원',
#  '18,000원',
#  '13,950원',
#  '14,400원',
#  '20,700원',
#  '17,100원',
#  '12,150원',
#  '12,150원',
#  '15,300원',
#  '13,500원',
#  '32,400원',
#  '22,950원',
#  '11,200원',
#  '30,600원',
#  '22,500원',
#  '23,400원',
#  '20,610원',
#  '17,550원',
#  '59,400원',
#  '15,300원',
#  '24,300원',
#  '11,700원',
#  '9,630원',
#  '12,150원',
#  '16,650원',
#  '13,500원',
#  '14,670원',
#  '9,900원',
#  '25,200원',
#  '15,300원',
#  '11,250원',
#  '8,190원',
#  '16,920원',
#  '15,300원',
#  '16,110원',
#  '17,910원',
#  '14,850원',
#  '15,750원',
#  '14,400원',
#  '14,400원',
#  '10,710원',
#  '13,500원',
#  '19,800원',
#  '14,400원',
#  '12,600원',
#  '13,500원',
#  '9,000원',
#  '14,400원',
#  '9,000원',
#  '12,100원',
#  '12,600원',
#  '13,500원',
#  '11,700원',
#  '13,320원',
#  '10,800원',
#  '14,400원',
#  '10,800원',
#  '16,920원',
#  '8,820원',
#  '16,000원',
#  '13,680원',
#  '11,700원',
#  '12,600원',
#  '9,900원',
#  '12,600원',
#  '17,820원',
#  '15,300원',
#  '9,900원',
#  '17,820원',
#  '10,620원',
#  '14,400원',
#  '19,800원',
#  '13,500원',
#  '8,910원',
#  '17,820원',
#  '11,700원',
#  '12,510원',
#  '14,940원',
#  '12,600원',
#  '15,300원',
#  '14,220원',
#  '14,400원',
#  '12,600원',
#  '8,820원',
#  '11,520원',
#  '11,700원',
#  '16,920원',
#  '13,500원',
#  '14,220원',
#  '6,600원',
#  '6,450원',
#  '9,900원',
#  '12,000원',
#  '7,500원',
#  '3,200원',
#  '2,900원',
#  '1,000원',
#  '22,500원',
#  '16,650원',
#  '23,400원',
#  '44,100원',
#  '13,500원',
#  '12,150원',
#  '13,500원',
#  '10,800원',
#  '10,800원',
#  '16,200원',
#  '15,300원',
#  '16,200원',
#  '14,220원',
#  '16,200원',
#  '4,950원',
#  '13,500원',
#  '9,000원',
#  '13,050원',
#  '13,500원',
#  '15,120원',
#  '13,950원',
#  '23,400원',
#  '18,000원',
#  '26,820원',
#  '19,800원',
#  '16,650원',
#  '20,700원',
#  '20,700원',
#  '13,050원',
#  '10,710원',
#  '14,850원',
#  '16,200원',
#  '19,800원',
#  '12,510원',
#  '18,000원',
#  '17,010원',
#  '29,700원',
#  '26,100원',
#  '8,820원',
#  '12,600원',
#  '17,550원',
#  '13,500원',
#  '24,300원',
#  '36,000원',
#  '5,850원',
#  '20,700원',
#  '14,400원',
#  '15,300원',
#  '18,000원',
#  '13,320원',
#  '13,410원',
#  '9,900원',
#  '6,660원',
#  '6,120원',
#  '10,710원',
#  '18,900원',
#  '16,650원',
#  '15,120원',
#  '17,910원',
#  '17,910원',
#  '14,850원',
#  '14,400원',
#  '14,400원',
#  '12,600원',
#  '10,710원',
#  '12,600원',
#  '10,800원',
#  '9,900원',
#  '14,400원',
#  '14,400원',
#  '11,250원',
#  '14,400원',
#  '16,200원',
#  '15,750원',
#  '15,300원',
#  '40,500원',
#  '14,400원',
#  '11,700원',
#  '8,820원',
#  '5,400원',
#  '8,910원',
#  '9,720원',
#  '11,700원',
#  '28,800원',
#  '8,910원',
#  '22,500원',
#  '13,050원',
#  '13,320원',
#  '9,900원',
#  '10,800원',
#  '13,050원',
#  '6,750원',
#  '6,300원',
#  '13,050원',
#  '13,410원',
#  '13,500원',
#  '9,900원',
#  '7,200원',
#  '19,800원',
#  '10,800원',
#  '18,000원',
#  '5,400원',
#  '5,500원',
#  '3,800원',
#  '5,880원',
#  '11,700원',
#  '16,200원',
#  '13,320원',
#  '17,820원',
#  '16,200원',
#  '8,080원',
#  '13,500원',
#  '12,150원',
#  '11,700원',
#  '15,120원',
#  '10,800원',
#  '5,350원',
#  '15,120원',
#  '16,650원',
#  '15,300원',
#  '13,500원',
#  '12,600원',
#  '14,220원',
#  '18,000원',
#  '14,400원',
#  '16,200원',
#  '17,550원',
#  '14,400원',
#  '22,500원',
#  '12,600원',
#  '16,110원',
#  '11,700원',
#  '15,120원',
#  '11,700원',
#  '10,800원',
#  '10,800원',
#  '10,800원',
#  '16,200원',
#  '10,800원',
#  '17,800원',
#  '18,400원',
#  '14,700원',
#  '13,900원',
#  '12,600원',
#  '11,550원',
#  '11,200원',
#  '4,100원',
#  '3,500원',
#  '3,000원',
#  '3,000원',
#  '3,000원',
#  '3,000원',
#  '2,900원',
#  '800원',
#  '500원',
#  '4,500원',
#  '31,500원',
#  '16,920원',
#  '14,400원',
#  '13,500원',
#  '41,400원',
#  '13,500원',
#  '13,500원',
#  '20,610원',
#  '27,000원',
#  '13,050원',
#  '28,500원',
#  '11,610원',
#  '9,000원',
#  '10,500원',
#  '11,700원',
#  '19,620원',
#  '14,400원',
#  '12,150원',
#  '16,200원',
#  '11,700원',
#  '10,800원',
#  '72,900원',
#  '13,500원',
#  '13,500원',
#  '39,600원',
#  '16,200원',
#  '14,400원',
#  '16,200원',
#  '13,320원',
#  '13,500원',
#  '13,500원',
#  '25,200원',
#  '15,300원',
#  '21,150원',
#  '18,900원',
#  '14,400원',
#  '14,400원',
#  '15,300원',
#  '25,200원',
#  '15,120원',
#  '13,500원',
#  '12,600원',
#  '12,600원',
#  '18,000원',
#  '10,800원',
#  '10,710원',
#  '16,200원',
#  '14,400원',
#  '13,500원',
#  '16,200원',
#  '12,600원',
#  '16,020원',
#  '13,050원',
#  '19,800원',
#  '19,800원',
#  '12,600원',
#  '15,300원',
#  '25,200원',
#  '17,010원',
#  '27,000원',
#  '17,550원',
#  '14,400원',
#  '22,500원',
#  '16,200원',
#  '13,680원',
#  '16,650원',
#  '12,150원',
#  '17,100원',
#  '12,600원',
#  '11,700원',
#  '15,120원',
#  '13,950원',
#  '22,500원',
#  '21,510원',
#  '13,410원',
#  '10,800원',
#  '16,200원',
#  '16,200원',
#  '14,400원',
#  '9,900원',
#  '5,040원',
#  '5,040원',
#  '17,910원',
#  '13,500원',
#  '13,410원',
#  '10,710원',
#  '15,750원',
#  '14,000원',
#  '14,400원',
#  '10,800원',
#  '21,600원',
#  '10,710원',
#  '14,400원',
#  '16,200원',
#  '13,500원',
#  '13,500원',
#  '11,700원',
#  '10,800원',
#  '8,000원',
#  '10,800원',
#  '5,400원',
#  '19,000원',
#  '13,500원',
#  '8,910원',
#  '5,400원',
#  '13,500원',
#  '10,800원',
#  '10,800원',
#  '11,700원',
#  '16,200원',
#  '10,800원',
#  '10,800원',
#  '21,600원',
#  '14,220원',
#  '15,120원',
#  '13,320원',
#  '14,400원',
#  '13,500원',
#  '16,200원',
#  '14,850원',
#  '11,250원',
#  '19,800원',
#  '13,320원',
#  '15,750원',
#  '9,900원',
#  '14,400원',
#  '18,000원',
#  '12,600원',
#  '13,500원',
#  '11,520원',
#  '10,800원',
#  '13,500원',
#  '7,200원',
#  '8,550원',
#  '11,700원',
#  '8,550원',
#  '8,550원',
#  '7,200원',
#  '13,500원',
#  '11,700원',
#  '20,700원',
#  '10,800원',
#  '8,100원',
#  '13,500원',
#  '12,600원',
#  '17,100원',
#  '11,700원',
#  '16,200원',
#  '7,920원',
#  '12,150원',
#  '11,700원',
#  '16,200원',
#  '18,000원',
#  '12,600원',
#  '9,900원',
#  '16,200원',
#  '14,400원',
#  '3,000원',
#  '13,950원',
#  '39,600원',
#  '16,200원',
#  '12,600원',
#  '11,250원',
#  '11,700원',
#  '12,510원',
#  '20,700원',
#  '17,820원',
#  '11,700원',
#  '10,800원',
#  '8,100원',
#  '17,820원',
#  '51,300원',
#  '31,320원',
#  '13,500원',
#  '14,400원',
#  '12,600원']

# %%
#5. txt에 저장
# codecs를 이용해서 kyobo_result.txt를 만들어 주세요.
# csv로 바꿀 수 있도록 처리해주시면 됩니다.
# 순위,제목,저자,가격
# 위 양식으로 해주시고, 순위는 그냥 순차적으로 다시 부여해주세요.
# 지금 제쪽 PC기준 1000등 책도 그냥 900등으로 기입하면 됩니다.

import codecs

f = codecs.open("C:/Users/jungm/Documents/crawler/kyobo_result.txt",encoding= "utf-8", mode="w") #utf-8 모든 랭귀지
f.write("순위, 제목, 저자, 가격\n")
for i in range(len(author_list)):
    f.write("%s, %s, %s, %s\n" % ((i+1),
                                 title_list[i].replace(",",""),
                                 author_list[i].replace(",",""),
                                 price_list[i].replace(",","")))
f.close()
